# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
appRank_free_playstore_19_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/appRank_free_playstore_2019.csv')
appRank_free_appstore_19_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/appRank_free_appstore_2019.csv')
appRank_pay_playstore_19_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/appRank_pay_playstore_2019.csv')
appRank_pay_appstore_19_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/appRank_pay_appstore_2019.csv')

# %%
appRank_free_playstore_20_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/appRank_free_playstore_2020.csv')
appRank_free_appstore_20_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/appRank_free_appstore_2020.csv')
appRank_pay_playstore_20_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/appRank_pay_playstore_2020.csv')
appRank_pay_appstore_20_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/appRank_pay_appstore_2020.csv')

# %%
appRank_sales_playstore_20_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/app_sales_rank_playstore_2020.csv')
appRank_sales_appstore_20_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/app_sales_rank_appstore_2020.csv')
appRank_sales_playstore_19_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/app_sales_rank_playstore_2019.csv')
appRank_sales_appstore_19_df = pd.read_csv('/content/gdrive/My Drive/dacon/app/app_sales_rank_appstore_2019.csv')

# %%
appRank_free_playstore_19_df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
tmp = [i for i in list(appRank_free_playstore_19_df) if 'gen' in i]
free_p_gen = list(set(np.array(appRank_free_playstore_19_df[tmp]).reshape(len(tmp)*50,)))
free_p_gen_dic_19 = []
for i in tmp:
  free_p_gen_dic_tmp = {key: 0 for key in dict.fromkeys(free_p_gen).keys()}
  score = 50
  for j in appRank_free_playstore_19_df.dropna()[i]:
    free_p_gen_dic_tmp[j] = free_p_gen_dic_tmp[j]+score
    score -= 1
  free_p_gen_dic_19.append(free_p_gen_dic_tmp)

print(free_p_gen_dic_19)
# Out:
# [{nan: 0, '동영상 플레이어/편집기': 72, '교육': 5, '쇼핑': 189, '도서/참고자료': 44, '생산성': 31, '날씨': 0, '만화': 0, '소셜': 84, '여행 및 지역정보': 60, '엔터테인먼트': 70, '건강/운동': 0, '금융': 218, '지도/내비게이션': 23, '사진': 74, '자동차': 0, '비즈니스': 0, '뉴스/잡지': 0, '음악/오디오': 48, '식음료': 97, '라이프스타일': 0, '부동산/홈 인테리어': 28, '도구': 166, '예술/디자인': 0, '커뮤니케이션': 65}, {nan: 0, '동영상 플레이어/편집기': 36, '교육': 48, '쇼핑': 104, '도서/참고자료': 43, '생산성': 39, '날씨': 7, '만화': 0, '소셜': 65, '여행 및 지역정보': 88, '엔터테인먼트': 62, '건강/운동': 0, '금융': 155, '지도/내비게이션': 72, '사진': 35, '자동차': 0, '비즈니스': 0, '뉴스/잡지': 0, '음악/오디오': 4, '식음료': 88, '라이프스타일': 0, '부동산/홈 인테리어': 46, '도구': 311, '예술/디자인': 0, '커뮤니케이션': 71}, {nan: 0, '동영상 플레이어/편집기': 33, '교육': 4, '쇼핑': 127, '도서/참고자료': 57, '생산성': 86, '날씨': 41, '만화': 0, '소셜': 88, '여행 및 지역정보': 70, '엔터테인먼트': 37, '건강/운동': 0, '금융': 302, '지도/내비게이션': 26, '사진': 25, '자동차': 0, '비즈니스': 0, '뉴스/잡지': 0, '음악/오디오': 12, '식음료': 47, '라이프스타일': 22, '부동산/홈 인테리어': 0, '도구': 229, '예술/디자인': 0, '커뮤니케이션': 68}, {nan: 0, '동영상 플레이어/편집기': 39, '교육': 12, '쇼핑': 86, '도서/참고자료': 73, '생산성': 24, '날씨': 36, '만화': 0, '소셜': 83, '여행 및 지역정보': 121, '엔터테인먼트': 165, '건강/운동': 0, '금융': 129, '지도/내비게이션': 40, '사진': 72, '자동차': 0, '비즈니스': 0, '뉴스/잡지': 0, '음악/오디오':
생산성': 100, '날씨': 0, '만화': 0, '소셜': 78, '여행 및 지역정보': 149, '엔터테인먼트': 32, '건강/운동': 14, '금융': 250, '지도/내비게이션': 51, '사진': 0, '자동차': 0, '비즈니스': 33, '뉴스/잡지': 16, '음악/오디오': 43, '식음료': 49, '라이프스타일': 20, '부동산/홈 인테리어': 11, '도구': 205, '예술/디자인': 0, '커뮤니케이션': 15}, {nan: 0, '동영상 플레이어/편집기': 90, '교육': 0, '쇼핑': 168, '도서/참고자료': 57, '생산성': 6, '날씨': 0, '만화': 0, '소셜': 89, '여행 및 지역정보': 160, '엔터테인먼트': 187, '건강/운동': 0, '금융': 142, '지도/내비게이션': 77, '사진': 66, '자동차': 0, '비즈니스': 3, '뉴스/잡지': 0, '음악/오디오': 0, '식음료': 89, '라이프스타일': 0, '부동산/홈 인테리어': 7, '도구': 90, '예술/디자인': 0, '커뮤니케이션': 43}]

# %%
col = []
for i in range(12):
  col.append('19_'+str(i+1))

free_playstore_19 = pd.DataFrame(free_p_gen_dic_19)
free_playstore_19 = free_playstore_19.T
free_playstore_19.columns = col
free_playstore_19 = free_playstore_19.drop([free_playstore_19.index[0]])
free_playstore_19.head()
# Out:
#               19_1  19_2  19_3  19_4  19_5  ...  19_8  19_9  19_10  19_11  19_12
# 동영상 플레이어/편집기    72    36    33    39    36  ...    33    31      0      0     90
# 교육               5    48     4    12     0  ...     0     0      0      0      0
# 쇼핑             189   104   127    86   105  ...   308   111    146    179    168
# 도서/참고자료         44    43    57    73    46  ...    27    42     32     29     57
# 생산성             31    39    86    24    52  ...     0     5     69    100      6
#
# [5 rows x 12 columns]

# %%
free_p_standard_19 = free_playstore_19[['19_1','19_2','19_3','19_4','19_5','19_6','19_7','19_8','19_9']]
free_p_standard_19 = free_p_standard_19.reset_index()
free_p_standard_19 = free_p_standard_19.set_index('index')
free_p_standard_19.head()
# Out:
#               19_1  19_2  19_3  19_4  19_5  19_6  19_7  19_8  19_9
# index
# 동영상 플레이어/편집기    72    36    33    39    36    35    43    33    31
# 교육               5    48     4    12     0     0     0     0     0
# 쇼핑             189   104   127    86   105   113   145   308   111
# 도서/참고자료         44    43    57    73    46    45    46    27    42
# 생산성             31    39    86    24    52    17    49     0     5

# %%
free_p_standard_19['average'] = 0.000
print(len(free_p_standard_19))
for i in range(24):
  total = 0
  for j in range(0,9):
    total += free_p_standard_19.iloc[i][j]
  free_p_standard_19['average'][i] = total/9

free_p_standard_19 = free_p_standard_19[['average']]
free_p_standard_19.head()
# Out:
# 24
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  average
# index
# 동영상 플레이어/편집기   39.777778
# 교육              7.666667
# 쇼핑            143.111111
# 도서/참고자료        47.000000
# 생산성            33.666667

# %%
free_p_standard_19 = free_p_standard_19.reset_index()
genre = list(free_p_standard_19['index'])
free_p_standard_19 = free_p_standard_19.set_index('index')
free_p_standard_19.head()
# Out:
#                  average
# index
# 동영상 플레이어/편집기   39.777778
# 교육              7.666667
# 쇼핑            143.111111
# 도서/참고자료        47.000000
# 생산성            33.666667

# %%
free_p_standard_19
# Out:
#                  average
# index
# 동영상 플레이어/편집기   39.777778
# 교육              7.666667
# 쇼핑            143.111111
# 도서/참고자료        47.000000
# 생산성            33.666667
# 날씨             23.555556
# 만화              0.888889
# 소셜             85.111111
# 여행 및 지역정보      95.111111
# 엔터테인먼트         91.555556
# 건강/운동           1.888889
# 금융            194.555556
# 지도/내비게이션       62.333333
# 사진             47.444444
# 자동차             1.333333
# 비즈니스            2.888889
# 뉴스/잡지           0.000000
# 음악/오디오         22.333333
# 식음료            75.333333
# 라이프스타일         26.555556
# 부동산/홈 인테리어     21.777778
# 도구            188.333333
# 예술/디자인          0.888889
# 커뮤니케이션         60.888889

# %%
print(genre)
# Out:
# ['동영상 플레이어/편집기', '교육', '쇼핑', '도서/참고자료', '생산성', '날씨', '만화', '소셜', '여행 및 지역정보', '엔터테인먼트', '건강/운동', '금융', '지도/내비게이션', '사진', '자동차', '비즈니스', '뉴스/잡지', '음악/오디오', '식음료', '라이프스타일', '부동산/홈 인테리어', '도구', '예술/디자인', '커뮤니케이션']

# %% [markdown]
# 증감율 계산:
# (현재 - 기준값) / 기준값

# %%
appRank_free_playstore_20_df.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
tmp = [i for i in list(appRank_free_playstore_20_df) if 'gen' in i]
free_p_gen = list(set(np.array(appRank_free_playstore_20_df[tmp]).reshape(len(tmp)*50,)))
free_p_gen_dic_20 = []
for i in tmp:
  free_p_gen_dic_tmp = {key: 0 for key in dict.fromkeys(free_p_gen).keys()}
  score = 50
  for j in appRank_free_playstore_20_df.dropna()[i]:
    free_p_gen_dic_tmp[j] = free_p_gen_dic_tmp[j]+score
    score -= 1
  free_p_gen_dic_20.append(free_p_gen_dic_tmp)

print(free_p_gen_dic_20)
# Out:
# [{'동영상 플레이어/편집기': 15, '교육': 0, '쇼핑': 213, '도서/참고자료': 53, '생산성': 39, '날씨': 0, '만화': 0, '소셜': 95, '엔터테인먼트': 91, '의료': 0, '건강/운동': 0, '여행 및 지역정보': 91, '금융': 291, '지도/내비게이션': 65, '자동차': 0, '사진': 0, '비즈니스': 0, '뉴스/잡지': 0, '음악/오디오': 0, '식음료': 73, '라이프스타일': 31, '부동산/홈 인테리어': 38, '도구': 137, '커뮤니케이션': 43}, {'동영상 플레이어/편집기': 0, '교육': 0, '쇼핑': 295, '도서/참고자료': 36, '생산성': 109, '날씨': 0, '만화': 0, '소셜': 74, '엔터테인먼트': 57, '의료': 62, '건강/운동': 48, '여행 및 지역정보': 8, '금융': 85, '지도/내비게이션': 0, '자동차': 40, '사진': 0, '비즈니스': 70, '뉴스/잡지': 0, '음악/오디오': 38, '식음료': 54, '라이프스타일': 97, '부동산/홈 인테리어': 23, '도구': 135, '커뮤니케이션': 44}, {'동영상 플레이어/편집기': 42, '교육': 57, '쇼핑': 228, '도서/참고자료': 56, '생산성': 43, '날씨': 0, '만화': 0, '소셜': 104, '엔터테인먼트': 84, '의료': 0, '건강/운동': 7, '여행 및 지역정보': 50, '금융': 182, '지도/내비게이션': 9, '자동차': 0, '사진': 12, '비즈니스': 49, '뉴스/잡지': 0, '음악/오디오': 54, '식음료': 83, '라이프스타일': 0, '부동산/홈 인테리어': 42, '도구': 92, '커뮤니케이션': 81}, {'동영상 플레이어/편집기': 28, '교육': 0, '쇼핑': 149, '도서/참고자료': 40, '생산성': 82, '날씨': 0, '만화': 0, '소셜': 81, '엔터테인먼트': 70, '의료': 0, '건강/운동': 0, '여행 및 지역정보': 29, '금융': 264, '지도/내비게이션': 17, '자동차': 48, '사진': 0, '비즈니스': 72, '뉴스/잡지': 0, '음악/오디오': 19, '식음료': 44, '라이프스타일': 0, '부동산/홈 인테리어': 36, '도구': 208, '커뮤니케이션': 88}, {'동영상 플레이어/편집기': 94, '교육': 0, '쇼핑': 127, '도서/참고자료': 46, '생산성': 48, '날씨': 48, '만화': 7, '소셜': 76, '엔터테인먼트': 64, '의료': 0, '건강/운동': 0, '여행 및 지역정보': 53, '금융': 213, '지도/내비게이션': 45, '자동차': 36, '사진': 0, '비즈니스': 72, '뉴스/잡지': 0, '음악/오디오': 50, '식음료': 50, '라이프스타일': 38, '부동산/홈 인테리어': 30, '도구': 134, '커뮤니케이션': 44}, {'동영상 플레이어/편집기': 99, '교육': 5, '쇼핑': 139, '도서/참고자료': 40, '생산성': 27, '날씨': 0, '만화': 0, '소셜': 60, '엔터테인먼트': 90, '의료': 0, '건강/운동': 1, '여행 및 지역정보': 49, '금융': 81, '지도/내비게이션': 82, '자동차': 0, '사진': 56, '비즈니스': 70, '뉴스/잡지': 38, '음악/오디오': 27, '식음료': 95, '라이프스타일': 0, '부동산/홈 인테리어': 47, '도구': 227, '커뮤니케이션': 42}]

# %%
col = []
for i in range(6):
  col.append('20_'+str(i+1))

free_playstore_20 = pd.DataFrame(free_p_gen_dic_20)
free_playstore_20 = free_playstore_20.T
free_playstore_20.columns = col
free_playstore_20 = free_playstore_20.drop([free_playstore_20.index[0]])
free_playstore_20.head()
# Out:
#          20_1  20_2  20_3  20_4  20_5  20_6
# 교육          0     0    57     0     0     5
# 쇼핑        213   295   228   149   127   139
# 도서/참고자료    53    36    56    40    46    40
# 생산성        39   109    43    82    48    27
# 날씨          0     0     0     0    48     0

# %%
col = []
for i in range(1,7):
  col.append(str(i)+'월')

print(col)
# Out:
# ['1월', '2월', '3월', '4월', '5월', '6월']

# %%
free_playstore_20 = free_playstore_20.reset_index()
free_playstore_20.head()
# Out:
#      index  20_1  20_2  20_3  20_4  20_5  20_6
# 0       교육     0     0    57     0     0     5
# 1       쇼핑   213   295   228   149   127   139
# 2  도서/참고자료    53    36    56    40    46    40
# 3      생산성    39   109    43    82    48    27
# 4       날씨     0     0     0     0    48     0

# %%
free_playstore_20.dtypes
# Out:
# index    object
# 20_1      int64
# 20_2      int64
# 20_3      int64
# 20_4      int64
# 20_5      int64
# 20_6      int64
# dtype: object

# %%
for i in range(len(col)):
  free_playstore_20[col[i]] = 0.000

for i in range(len(free_playstore_20)):
  base = free_playstore_20['index'][i]
  if base in genre:
    idx = genre.index(base)
    base = free_p_standard_19.iloc[idx]['average']
  else:
    base = 1.0
  for j in range(2, 8):
    if base == 0:
      value = 0.0
    else:
      value = (float(free_playstore_20.iloc[i][j]) - base) / base
    free_playstore_20[col[j-2]][i] = value

free_playstore_20.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 17      음악/오디오   0.701493   1.417910  ...   1.238806   0.208955  -0.968590
# 18         식음료  -0.283186   0.101770  ...  -0.336283   0.261062  -1.003759
# 19      라이프스타일   2.652720  -1.000000  ...   0.430962  -1.000000  -0.900107
# 20  부동산/홈 인테리어   0.056122   0.928571  ...   0.377551   1.158163  -0.997423
# 21          도구  -0.283186  -0.511504  ...  -0.288496   0.205310  -1.001504
# 22      커뮤니케이션  -0.277372   0.330292  ...  -0.277372  -0.310219  -1.004555
#
# [23 rows x 7 columns]

# %%
month = list()
for i in range(1,7):
  month.append(list(free_playstore_20[str(i)+'월']))

# %%
genre_list = list(free_playstore_20['genre'])
print(len(genre_list))
# Out:
# 23

# %%
free_playstore_20_graph = pd.DataFrame()
for i in range(6):
  free_playstore_20_fig = pd.DataFrame(genre_list,columns = ['genre'])
  free_playstore_20_fig['value'] = month[i]
  free_playstore_20_fig['month'] = str(i+1)+'월'
  free_playstore_20_fig = free_playstore_20_fig[['genre','month','value']]
  free_playstore_20_graph = pd.concat([free_playstore_20_graph,free_playstore_20_fig], axis = 0)

free_playstore_20_graph
# Out:
#          genre month     value
# 0           교육    1월 -1.000000
# 1           쇼핑    1월  1.061335
# 2      도서/참고자료    1월 -0.234043
# 3          생산성    1월  2.237624
# 4           날씨    1월 -1.000000
# ..         ...   ...       ...
# 18         식음료    6월 -1.003759
# 19      라이프스타일    6월 -0.900107
# 20  부동산/홈 인테리어    6월 -0.997423
# 21          도구    6월 -1.001504
# 22      커뮤니케이션    6월 -1.004555
#
# [138 rows x 3 columns]

# %%
df = free_playstore_20_graph

fig = px.bar(df, x="genre", y="value", color="genre",
  animation_frame="month", animation_group="genre", range_y=[-5, 65])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="54a75ec3-3ba8-4833-b6f0-c6fb05b6349b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54a75ec3-3ba8-4833-b6f0-c6fb05b6349b")) {
#                     Plotly.newPlot(
#                         '54a75ec3-3ba8-4833-b6f0-c6fb05b6349b',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uad50\uc721"], "legendgroup": "genre=\uad50\uc721", "marker": {"color": "#636efa"}, "name": "genre=\uad50\uc721", "offsetgroup": "genre=\uad50\uc721", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uad50\uc721"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc1fc\ud551"], "legendgroup": "genre=\uc1fc\ud551", "marker": {"color": "#EF553B"}, "name": "genre=\uc1fc\ud551", "offsetgroup": "genre=\uc1fc\ud551", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc1fc\ud551"], "xaxis": "x", "y": [1.061335403726708], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc"], "legendgroup": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "marker": {"color": "#00cc96"}, "name": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "offsetgroup": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc"], "xaxis": "x", "y": [-0.23404255319148937], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc0dd\uc0b0\uc131"], "legendgroup": "genre=\uc0dd\uc0b0\uc131", "marker": {"color": "#ab63fa"}, "name": "genre=\uc0dd\uc0b0\uc131", "offsetgroup": "genre=\uc0dd\uc0b0\uc131", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc0dd\uc0b0\uc131"], "xaxis": "x", "y": [2.2376237623762383], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub0a0\uc528"], "legendgroup": "genre=\ub0a0\uc528", "marker": {"color": "#FFA15A"}, "name": "genre=\ub0a0\uc528", "offsetgroup": "genre=\ub0a0\uc528", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub0a0\uc528"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub9cc\ud654"], "legendgroup": "genre=\ub9cc\ud654", "marker": {"color": "#19d3f3"}, "name": "genre=\ub9cc\ud654", "offsetgroup": "genre=\ub9cc\ud654", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub9cc\ud654"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc18c\uc15c"], "legendgroup": "genre=\uc18c\uc15c", "marker": {"color": "#FF6692"}, "name": "genre=\uc18c\uc15c", "offsetgroup": "genre=\uc18c\uc15c", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc18c\uc15c"], "xaxis": "x", "y": [-0.1305483028720627], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "legendgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "marker": {"color": "#B6E880"}, "name": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "offsetgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "xaxis": "x", "y": [-0.3774271844660194], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc758\ub8cc"], "legendgroup": "genre=\uc758\ub8cc", "marker": {"color": "#FF97F ...

# %%
appRank_pay_playstore_19_df.drop(['Unnamed: 0'], axis = 1, inplace= True)
appRank_pay_playstore_19_df.head()
# Out:
#             19_1  ...     19_12_gen
# 0  유니콘:광고차단 필수 앱  ...         맞춤 설정
# 1         Tasker  ...           생산성
# 2          갓피플성경  ...       도서/참고자료
# 3        nPlayer  ...  동영상 플레이어/편집기
# 4   LectureNotes  ...            교육
#
# [5 rows x 24 columns]

# %%
tmp = [i for i in list(appRank_pay_playstore_19_df) if 'gen' in i]
pay_p_gen = list(set(np.array(appRank_pay_playstore_19_df[tmp]).reshape(len(tmp)*50,)))
pay_p_gen_dic_19 = []
for i in tmp:
  pay_p_gen_dic_tmp = {key: 0 for key in dict.fromkeys(pay_p_gen).keys()}
  score = 50
  for j in appRank_pay_playstore_19_df.dropna()[i]:
    pay_p_gen_dic_tmp[j] = pay_p_gen_dic_tmp[j]+score
    score -= 1
  pay_p_gen_dic_19.append(pay_p_gen_dic_tmp)

print(pay_p_gen_dic_19)
# Out:
# [{'동영상 플레이어/편집기': 141, '교육': 135, '여행 및 지역정보': 0, '의료': 0, '라이프스타일': 4, '엔터테인먼트': 13, '건강/운동': 0, '도서/참고자료': 77, '금융': 25, '지도/내비게이션': 0, '사진': 181, '생산성': 124, '도구': 163, '날씨': 0, '비즈니스': 39, '출산/육아': 0, '맞춤 설정': 198, '음악/오디오': 119, '만화': 26, '커뮤니케이션': 30}, {'동영상 플레이어/편집기': 112, '교육': 110, '여행 및 지역정보': 4, '의료': 0, '라이프스타일': 20, '엔터테인먼트': 26, '건강/운동': 0, '도서/참고자료': 109, '금융': 22, '지도/내비게이션': 0, '사진': 110, '생산성': 147, '도구': 157, '날씨': 19, '비즈니스': 41, '출산/육아': 0, '맞춤 설정': 158, '음악/오디오': 140, '만화': 23, '커뮤니케이션': 77}, {'동영상 플레이어/편집기': 136, '교육': 122, '여행 및 지역정보': 0, '의료': 0, '라이프스타일': 18, '엔터테인먼트': 0, '건강/운동': 0, '도서/참고자료': 47, '금융': 0, '지도/내비게이션': 0, '사진': 197, '생산성': 158, '도구': 196, '날씨': 40, '비즈니스': 36, '출산/육아': 0, '맞춤 설정': 144, '음악/오디오': 90, '만화': 11, '커뮤니케이션': 80}, {'동영상 플레이어/편집기': 177, '교육': 84, '여행 및 지역정보': 0, '의료': 0, '라이프스타일': 45, '엔터테인먼트': 5, '건강/운동': 0, '도서/참고자료': 77, '금융': 21, '지도/내비게이션': 0, '사진': 150, '생산성': 156, '도구': 188, '날씨': 0, '
# %%
col = []
for i in range(12):
  col.append('19_'+str(i+1))

pay_playstore_19 = pd.DataFrame(pay_p_gen_dic_19)
pay_playstore_19 = pay_playstore_19.T
pay_playstore_19.columns = col
pay_playstore_19 = pay_playstore_19.drop([pay_playstore_19.index[0]])
pay_playstore_19.head()
# Out:
#            19_1  19_2  19_3  19_4  19_5  ...  19_8  19_9  19_10  19_11  19_12
# 교육          135   110   122    84    86  ...   151    92    157    146    177
# 여행 및 지역정보     0     4     0     0     1  ...     0     3     41      0      0
# 의료            0     0     0     0     0  ...     0     0      0     83      0
# 라이프스타일        4    20    18    45    50  ...    23    39     48     66     14
# 엔터테인먼트       13    26     0     5    27  ...     3    22      0      0     13
#
# [5 rows x 12 columns]

# %%
pay_p_standard_19 = pay_playstore_19[['19_1','19_2','19_3','19_4','19_5','19_6','19_7','19_8','19_9']]
pay_p_standard_19 = pay_p_standard_19.reset_index()
pay_p_standard_19 = pay_p_standard_19.set_index('index')
pay_p_standard_19.head()
# Out:
#            19_1  19_2  19_3  19_4  19_5  19_6  19_7  19_8  19_9
# index
# 교육          135   110   122    84    86   151   172   151    92
# 여행 및 지역정보     0     4     0     0     1    13     0     0     3
# 의료            0     0     0     0     0     0     0     0     0
# 라이프스타일        4    20    18    45    50    59    32    23    39
# 엔터테인먼트       13    26     0     5    27    24     6     3    22

# %%
pay_p_standard_19['average'] = 0.000
for i in range(len(pay_p_standard_19)):
  total = 0
  for j in range(0,9):
    total += pay_p_standard_19.iloc[i][j]
  pay_p_standard_19['average'][i] = total/9

pay_p_standard_19 = pay_p_standard_19[['average']]
pay_p_standard_19.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               average
# index
# 교육         122.555556
# 여행 및 지역정보    2.333333
# 의료           0.000000
# 라이프스타일      32.222222
# 엔터테인먼트      14.000000

# %%
pay_p_standard_19 = pay_p_standard_19.reset_index()
genre = list(pay_p_standard_19['index'])
pay_p_standard_19 = pay_p_standard_19.set_index('index')
pay_p_standard_19.head()
# Out:
#               average
# index
# 교육         122.555556
# 여행 및 지역정보    2.333333
# 의료           0.000000
# 라이프스타일      32.222222
# 엔터테인먼트      14.000000

# %%
print(genre)
# Out:
# ['교육', '여행 및 지역정보', '의료', '라이프스타일', '엔터테인먼트', '건강/운동', '도서/참고자료', '금융', '지도/내비게이션', '사진', '생산성', '도구', '날씨', '비즈니스', '출산/육아', '맞춤 설정', '음악/오디오', '만화', '커뮤니케이션']

# %%
appRank_pay_playstore_20_df.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
tmp = [i for i in list(appRank_pay_playstore_20_df) if 'gen' in i]
pay_p_gen = list(set(np.array(appRank_pay_playstore_20_df[tmp]).reshape(len(tmp)*50,)))
pay_p_gen_dic_20 = []
for i in tmp:
  pay_p_gen_dic_tmp = {key: 0 for key in dict.fromkeys(pay_p_gen).keys()}
  score = 50
  for j in appRank_pay_playstore_20_df.dropna()[i]:
    pay_p_gen_dic_tmp[j] = pay_p_gen_dic_tmp[j]+score
    score -= 1
  pay_p_gen_dic_20.append(pay_p_gen_dic_tmp)

print(pay_p_gen_dic_20)
# Out:
# [{'동영상 플레이어/편집기': 91, '교육': 205, '소셜': 0, '엔터테인먼트': 51, '라이프스타일': 25, '여행 및 지역정보': 15, '이벤트': 0, '도서/참고자료': 48, '금융': 31, '사진': 211, '생산성': 162, '도구': 111, '자동차': 9, '비즈니스': 39, '맞춤 설정': 103, '음악/오디오': 90, '만화': 13, '예술/디자인': 0, '커뮤니케이션': 71}, {'동영상 플레이어/편집기': 99, '교육': 132, '소셜': 14, '엔터테인먼트': 0, '라이프스타일': 1, '여행 및 지역정보': 0, '이벤트': 0, '도서/참고자료': 75, '금융': 26, '사진': 207, '생산성': 231, '도구': 119, '자동차': 0, '비즈니스': 41, '맞춤 설정': 129, '음악/오디오': 112, '만화': 16, '예술/디자인': 0, '커뮤니케이션': 73}, {'동영상 플레이어/편집기': 90, '교육': 129, '소셜': 0, '엔터테인먼트': 0, '라이프스타일': 19, '여행 및 지역정보': 0, '이벤트': 0, '도서/참고자료': 96, '금융': 25, '사진': 236, '생산성': 234, '도구': 144, '자동차': 0, '비즈니스': 46, '맞춤 설정': 84, '음악/오디오': 83, '만화': 26, '예술/디자인': 0, '커뮤니케이션': 63}, {'동영상 플레이어/편집기': 89, '교육': 117, '소셜': 0, '엔터테인먼트': 0, '라이프스타일': 0, '여행 및 지역정보': 40, '이벤트': 6, '도서/참고자료': 117, '금융': 23, '사진': 227, '생산성': 178, '도구': 165, '자동차': 21, '비즈니스': 47, '맞춤 설정': 67, '음악/오디오': 77, '만화': 20, '예술/디자인': 4, '커뮤니케이션': 77}, {'동영상 플레이어/편집기': 99, '교육': 65, '소셜': 0, '엔터테인먼트': 0, '라이프스타일': 25, '여행 및 지역정보': 16, '이벤트': 0, '도서/참고자료': 101, '금융': 27, '사진': 183, '생산성': 180, '도구': 166, '자동차': 0, '비즈니스': 45, '맞춤 설정': 109, '음악/오디오': 140, '만화': 32, '예술/디자인': 14, '커뮤니케이션': 73}, {'동영상 플레이어/편집기': 101, '교육': 104, '소셜': 0, '엔터테인먼트': 0, '라이프스타일': 36, '여행 및 지역정보': 0, '이벤트': 0, '도서/참고자료': 94, '금융': 27, '사진': 171, '생산성': 169, '도구': 203, '자동차': 0, '비즈니스': 46, '맞춤 설정': 94, '음악/오디오': 122, '만화': 26, '예술/디자인': 0, '커뮤니케이션': 82}]

# %%
col = []
for i in range(6):
  col.append('20_'+str(i+1))

pay_playstore_20 = pd.DataFrame(pay_p_gen_dic_20)
pay_playstore_20 = pay_playstore_20.T
pay_playstore_20.columns = col
pay_playstore_20 = pay_playstore_20.drop([pay_playstore_20.index[0]])
pay_playstore_20.head()
# Out:
#            20_1  20_2  20_3  20_4  20_5  20_6
# 교육          205   132   129   117    65   104
# 소셜            0    14     0     0     0     0
# 엔터테인먼트       51     0     0     0     0     0
# 라이프스타일       25     1    19     0    25    36
# 여행 및 지역정보    15     0     0    40    16     0

# %%
col = []
for i in range(1,7):
  col.append(str(i)+'월')

print(col)
# Out:
# ['1월', '2월', '3월', '4월', '5월', '6월']

# %%
pay_playstore_20 = pay_playstore_20.reset_index()
pay_playstore_20.head()
# Out:
#        index  20_1  20_2  20_3  20_4  20_5  20_6
# 0         교육   205   132   129   117    65   104
# 1         소셜     0    14     0     0     0     0
# 2     엔터테인먼트    51     0     0     0     0     0
# 3     라이프스타일    25     1    19     0    25    36
# 4  여행 및 지역정보    15     0     0    40    16     0

# %%
for i in range(len(col)):
  pay_playstore_20[col[i]] = 0.000

for i in range(len(pay_playstore_20)):
  base = pay_playstore_20['index'][i]
  if base in genre:
    idx = genre.index(base)
    base = pay_p_standard_19.iloc[idx]['average']
  else:
    base = 1.0
  for j in range(2, 8):
    if base == 0:
      value = 0.0
    else:
      value = (float(pay_playstore_20.iloc[i][j]) - base) / base
    pay_playstore_20[col[j-2]][i] = value

pay_playstore_20.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        index  20_1  20_2  20_3  ...         3월        4월        5월         6월
# 0         교육   205   132   129  ...  -0.045331 -0.469628 -0.151405  -0.999371
# 1         소셜     0    14     0  ...  -1.000000 -1.000000 -1.000000  12.000000
# 2     엔터테인먼트    51     0     0  ...  -1.000000 -1.000000 -1.000000  -1.071429
# 3     라이프스타일    25     1    19  ...  -1.000000 -0.224138  0.117241  -1.030071
# 4  여행 및 지역정보    15     0     0  ...  16.142857  5.857143 -1.000000  -1.428571
#
# [5 rows x 13 columns]

# %%
pay_playstore_20 = pay_playstore_20.set_index('index')
pay_playstore_20 = pay_playstore_20[['1월','2월','3월','4월','5월','6월']]
pay_playstore_20
# Out:
#                   1월        2월         3월         4월        5월         6월
# index
# 교육          0.077063  0.052584  -0.045331  -0.469628 -0.151405  -0.999371
# 소셜         13.000000 -1.000000  -1.000000  -1.000000 -1.000000  12.000000
# 엔터테인먼트     -1.000000 -1.000000  -1.000000  -1.000000 -1.000000  -1.071429
# 라이프스타일     -0.968966 -0.410345  -1.000000  -0.224138  0.117241  -1.030071
# 여행 및 지역정보  -1.000000 -1.000000  16.142857   5.857143 -1.000000  -1.428571
# 이벤트        -1.000000 -1.000000   5.000000  -1.000000 -1.000000  -2.000000
# 도서/참고자료     0.048137  0.341615   0.635093   0.411491  0.313665  -0.999327
# 금융          0.244681  0.196809   0.101064   0.292553  0.292553  -0.988287
# 사진          0.260487  0.437077   0.382273   0.114344  0.041272  -0.998414
# 생산성         0.550336  0.570470   0.194631   0.208054  0.134228  -0.996306
# 도구         -0.295858 -0.147929  -0.023669  -0.017751  0.201183  -1.001751
# 자동차        -1.000000 -1.000000  20.000000  -1.000000 -1.000000  -2.000000
# 비즈니스       -0.104369  0.004854   0.026699  -0.016990  0.004854  -1.002280
# 맞춤 설정      -0.050695 -0.381848  -0.506950  -0.197874 -0.308258  -1.000373
# 음악/오디오      0.095652 -0.188043  -0.246739   0.369565  0.193478  -0.999064
# 만화          0.285714  1.089286   0.607143   1.571429  1.089286  -0.977041
# 예술/디자인     -1.000000 -1.000000   3.000000  13.000000 -1.000000  -2.000000
# 커뮤니케이션     -0.020864 -0.154993   0.032787  -0.020864  0.099851  -1.000280

# %%
pay_playstore_20 = pay_playstore_20.reset_index()
pay_playstore_20
# Out:
#         index         1월        2월         3월         4월        5월         6월
# 0          교육   0.077063  0.052584  -0.045331  -0.469628 -0.151405  -0.999371
# 1          소셜  13.000000 -1.000000  -1.000000  -1.000000 -1.000000  12.000000
# 2      엔터테인먼트  -1.000000 -1.000000  -1.000000  -1.000000 -1.000000  -1.071429
# 3      라이프스타일  -0.968966 -0.410345  -1.000000  -0.224138  0.117241  -1.030071
# 4   여행 및 지역정보  -1.000000 -1.000000  16.142857   5.857143 -1.000000  -1.428571
# 5         이벤트  -1.000000 -1.000000   5.000000  -1.000000 -1.000000  -2.000000
# 6     도서/참고자료   0.048137  0.341615   0.635093   0.411491  0.313665  -0.999327
# 7          금융   0.244681  0.196809   0.101064   0.292553  0.292553  -0.988287
# 8          사진   0.260487  0.437077   0.382273   0.114344  0.041272  -0.998414
# 9         생산성   0.550336  0.570470   0.194631   0.208054  0.134228  -0.996306
# 10         도구  -0.295858 -0.147929  -0.023669  -0.017751  0.201183  -1.001751
# 11        자동차  -1.000000 -1.000000  20.000000  -1.000000 -1.000000  -2.000000
# 12       비즈니스  -0.104369  0.004854   0.026699  -0.016990  0.004854  -1.002280
# 13      맞춤 설정  -0.050695 -0.381848  -0.506950  -0.197874 -0.308258  -1.000373
# 14     음악/오디오   0.095652 -0.188043  -0.246739   0.369565  0.193478  -0.999064
# 15         만화   0.285714  1.089286   0.607143   1.571429  1.089286  -0.977041
# 16     예술/디자인  -1.000000 -1.000000   3.000000  13.000000 -1.000000  -2.000000
# 17     커뮤니케이션  -0.020864 -0.154993   0.032787  -0.020864  0.099851  -1.000280

# %%
month = list()
for i in range(1,7):
  month.append(list(pay_playstore_20[str(i)+'월']))

# %%
genre_list = list(pay_playstore_20['index'])
print(len(genre_list))
# Out:
# 18

# %%
pay_playstore_20_graph = pd.DataFrame()
for i in range(6):
  pay_playstore_20_fig = pd.DataFrame(genre_list,columns = ['genre'])
  pay_playstore_20_fig['value'] = month[i]
  pay_playstore_20_fig['month'] = str(i+1)+'월'
  pay_playstore_20_fig = pay_playstore_20_fig[['genre','month','value']]
  pay_playstore_20_graph = pd.concat([pay_playstore_20_graph,pay_playstore_20_fig], axis = 0)

pay_playstore_20_graph
# Out:
#         genre month      value
# 0          교육    1월   0.077063
# 1          소셜    1월  13.000000
# 2      엔터테인먼트    1월  -1.000000
# 3      라이프스타일    1월  -0.968966
# 4   여행 및 지역정보    1월  -1.000000
# ..        ...   ...        ...
# 13      맞춤 설정    6월  -1.000373
# 14     음악/오디오    6월  -0.999064
# 15         만화    6월  -0.977041
# 16     예술/디자인    6월  -2.000000
# 17     커뮤니케이션    6월  -1.000280
#
# [108 rows x 3 columns]

# %%
df = pay_playstore_20_graph

fig = px.bar(df, x="genre", y="value", color="genre",
  animation_frame="month", animation_group="genre", range_y=[-5, 22])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9f6056f3-b2df-40d7-ba58-5d51185ea0ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f6056f3-b2df-40d7-ba58-5d51185ea0ab")) {
#                     Plotly.newPlot(
#                         '9f6056f3-b2df-40d7-ba58-5d51185ea0ab',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uad50\uc721"], "legendgroup": "genre=\uad50\uc721", "marker": {"color": "#636efa"}, "name": "genre=\uad50\uc721", "offsetgroup": "genre=\uad50\uc721", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uad50\uc721"], "xaxis": "x", "y": [0.07706255666364459], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc18c\uc15c"], "legendgroup": "genre=\uc18c\uc15c", "marker": {"color": "#EF553B"}, "name": "genre=\uc18c\uc15c", "offsetgroup": "genre=\uc18c\uc15c", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc18c\uc15c"], "xaxis": "x", "y": [13.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "legendgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "marker": {"color": "#00cc96"}, "name": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "offsetgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c"], "legendgroup": "genre=\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c", "marker": {"color": "#ab63fa"}, "name": "genre=\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c", "offsetgroup": "genre=\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c"], "xaxis": "x", "y": [-0.9689655172413794], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc5ec\ud589 \ubc0f \uc9c0\uc5ed\uc815\ubcf4"], "legendgroup": "genre=\uc5ec\ud589 \ubc0f \uc9c0\uc5ed\uc815\ubcf4", "marker": {"color": "#FFA15A"}, "name": "genre=\uc5ec\ud589 \ubc0f \uc9c0\uc5ed\uc815\ubcf4", "offsetgroup": "genre=\uc5ec\ud589 \ubc0f \uc9c0\uc5ed\uc815\ubcf4", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc5ec\ud589 \ubc0f \uc9c0\uc5ed\uc815\ubcf4"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc774\ubca4\ud2b8"], "legendgroup": "genre=\uc774\ubca4\ud2b8", "marker": {"color": "#19d3f3"}, "name": "genre=\uc774\ubca4\ud2b8", "offsetgroup": "genre=\uc774\ubca4\ud2b8", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc774\ubca4\ud2b8"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc"], "legendgroup": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "marker": {"color": "#FF6692"}, "name": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "offsetgroup": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc"], "xaxis": "x", "y": [0.0481366459627329], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uae08\uc735"], "legendgroup": "genre=\uae08\uc735", "marker": {"color": "#B6E880"}, "name": "genre=\uae08\uc735", "offsetgroup": "genre=\uae08\uc735", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uae08\uc735"], "x ...

# %%
appRank_sales_playstore_19_df.drop(['Unnamed: 0'],axis=1,inplace= True)

# %%
tmp = [i for i in list(appRank_sales_playstore_19_df) if 'gen' in i]
sales_p_gen = list(set(np.array(appRank_sales_playstore_19_df[tmp]).reshape(len(tmp)*50,)))
sales_p_gen_dic_19 = []
for i in tmp:
  sales_p_gen_dic_tmp = {key: 0 for key in dict.fromkeys(sales_p_gen).keys()}
  score = 50
  for j in appRank_sales_playstore_19_df.dropna()[i]:
    sales_p_gen_dic_tmp[j] = sales_p_gen_dic_tmp[j]+score
    score -= 1
  sales_p_gen_dic_19.append(sales_p_gen_dic_tmp)

# %%
col = []
for i in range(6,12):
  col.append('19_'+str(i+1))

sales_playstore_19 = pd.DataFrame(sales_p_gen_dic_19)
sales_playstore_19 = sales_playstore_19.T
sales_playstore_19.columns = col
sales_playstore_19 = sales_playstore_19.drop([sales_playstore_19.index[0]])
sales_playstore_19.head()
# Out:
#         19_7  19_8  19_9  19_10  19_11  19_12
# 소셜       413   521   472    417    478    481
# 교육        48    32    15     20     25     55
# 엔터테인먼트   292   157   250    287    217    245
# 라이프스타일    71    78    89     80     78     51
# 어드벤처      44     0     0      0      0      0

# %%
sales_playstore_19 = sales_playstore_19.reset_index()
sales_playstore_19 = sales_playstore_19.set_index('index')
sales_playstore_19.head()
# Out:
#         19_7  19_8  19_9  19_10  19_11  19_12
# index
# 소셜       413   521   472    417    478    481
# 교육        48    32    15     20     25     55
# 엔터테인먼트   292   157   250    287    217    245
# 라이프스타일    71    78    89     80     78     51
# 어드벤처      44     0     0      0      0      0

# %%
sales_playstore_19['average'] = 0.000

for i in range(len(sales_playstore_19)):
  total = 0
  for j in range(0,6):
    total += sales_playstore_19.iloc[i][j]
  sales_playstore_19['average'][i] = total/9

sales_playstore_19 = sales_playstore_19[['average']]
sales_playstore_19.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            average
# index
# 소셜      309.111111
# 교육       21.666667
# 엔터테인먼트  160.888889
# 라이프스타일   49.666667
# 어드벤처      4.888889

# %%
sales_playstore_19 = sales_playstore_19.reset_index()
genre = list(sales_playstore_19['index'])
sales_playstore_19 = sales_playstore_19.set_index('index')
sales_playstore_19.head()
# Out:
#            average
# index
# 소셜      309.111111
# 교육       21.666667
# 엔터테인먼트  160.888889
# 라이프스타일   49.666667
# 어드벤처      4.888889

# %%
sales_playstore_19
# Out:
#             average
# index
# 소셜       309.111111
# 교육        21.666667
# 엔터테인먼트   160.888889
# 라이프스타일    49.666667
# 어드벤처       4.888889
# 스포츠       33.444444
# 도서/참고자료   25.666667
# 생산성       31.444444
# 사진         0.333333
# 도구         4.555556
# 데이트       83.222222
# 음악/오디오     7.111111
# 커뮤니케이션    86.000000

# %%
appRank_sales_playstore_20_df.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
tmp = [i for i in list(appRank_sales_playstore_20_df) if 'gen' in i]
sales_p_gen = list(set(np.array(appRank_sales_playstore_20_df[tmp]).reshape(len(tmp)*50,)))
sales_p_gen_dic_20 = []
for i in tmp:
  sales_p_gen_dic_tmp = {key: 0 for key in dict.fromkeys(sales_p_gen).keys()}
  score = 50
  for j in appRank_sales_playstore_20_df.dropna()[i]:
    sales_p_gen_dic_tmp[j] = sales_p_gen_dic_tmp[j]+score
    score -= 1
  sales_p_gen_dic_20.append(sales_p_gen_dic_tmp)

# %%
col = []
for i in range(6):
  col.append('20_'+str(i+1))

sales_playstore_20 = pd.DataFrame(sales_p_gen_dic_20)
sales_playstore_20 = sales_playstore_20.T
sales_playstore_20.columns = col
sales_playstore_20 = sales_playstore_20.drop([sales_playstore_20.index[0]])
sales_playstore_20.head()
# Out:
#         20_1  20_2  20_3  20_4  20_5  20_6
# 소셜       496   482   503   479   469   463
# 교육        54    66    59    58    66    43
# 엔터테인먼트   217   198   219   223   266   206
# 스포츠       57    61     0     0    12    44
# 라이프스타일    49    37    36    37    35    32

# %%
col = []
for i in range(1,7):
  col.append(str(i)+'월')

print(col)
# Out:
# ['1월', '2월', '3월', '4월', '5월', '6월']

# %%
sales_playstore_20 = sales_playstore_20.reset_index()
sales_playstore_20.head()
# Out:
#     index  20_1  20_2  20_3  20_4  20_5  20_6
# 0      소셜   496   482   503   479   469   463
# 1      교육    54    66    59    58    66    43
# 2  엔터테인먼트   217   198   219   223   266   206
# 3     스포츠    57    61     0     0    12    44
# 4  라이프스타일    49    37    36    37    35    32

# %%
for i in range(len(col)):
  sales_playstore_20[col[i]] = 0.000

for i in range(len(sales_playstore_20)):
  base = sales_playstore_20['index'][i]
  if base in genre:
    idx = genre.index(base)
    base = sales_playstore_19.iloc[idx]['average']
  else:
    base = 1.0
  for j in range(2, 8):
    if base == 0:
      value = 0.0
    else:
      value = (float(sales_playstore_20.iloc[i][j]) - base) / base
    sales_playstore_20[col[j-2]][i] = value

sales_playstore_20.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     index  20_1  20_2  20_3  ...        3월        4월        5월        6월
# 0      소셜   496   482   503  ...  0.549605  0.517254  0.497843 -0.998191
# 1      교육    54    66    59  ...  1.676923  2.046154  0.984615 -0.905562
# 2  엔터테인먼트   217   198   219  ...  0.386050  0.653315  0.280387 -0.998566
# 3     스포츠    57    61     0  ... -1.000000 -0.641196  0.315615 -0.975365
# 4  라이프스타일    49    37    36  ... -0.255034 -0.295302 -0.355705 -1.005135
#
# [5 rows x 13 columns]

# %%
sales_playstore_20 = sales_playstore_20.set_index('index')
sales_playstore_20 = sales_playstore_20[['1월','2월','3월','4월','5월','6월']]
sales_playstore_20 = sales_playstore_20.reset_index()
sales_playstore_20
# Out:
#       index        1월        2월         3월         4월         5월        6월
# 0        소셜  0.559310  0.627247   0.549605   0.517254   0.497843 -0.998191
# 1        교육  2.046154  1.723077   1.676923   2.046154   0.984615 -0.905562
# 2    엔터테인먼트  0.230663  0.361188   0.386050   0.653315   0.280387 -0.998566
# 3       스포츠  0.823920 -1.000000  -1.000000  -0.641196   0.315615 -0.975365
# 4    라이프스타일 -0.255034 -0.275168  -0.255034  -0.295302  -0.355705 -1.005135
# 5   도서/참고자료  0.441558  0.480519   0.480519   0.363636   0.402597 -0.982796
# 6        금융 -1.000000  9.000000  16.000000  10.000000  20.000000 -2.000000
# 7       생산성  0.749117  0.939929   0.971731   0.621908   0.685512 -0.976177
# 8       데이트  0.610147  0.766355   0.766355   0.850467   1.018692 -0.992668
# 9    음악/오디오  0.406250  0.265625   0.406250  -0.015625  -0.156250 -0.942871
# 10       만화  7.000000 -1.000000  11.000000  -1.000000  -1.000000  6.000000
# 11   커뮤니케이션  0.639535  0.627907   0.616279   0.604651   1.023256 -0.992564

# %%
sales_playstore_20.columns = ['genre', '1월','2월','3월','4월','5월','6월']
sales_playstore_20
# Out:
#       genre        1월        2월         3월         4월         5월        6월
# 0        소셜  0.559310  0.627247   0.549605   0.517254   0.497843 -0.998191
# 1        교육  2.046154  1.723077   1.676923   2.046154   0.984615 -0.905562
# 2    엔터테인먼트  0.230663  0.361188   0.386050   0.653315   0.280387 -0.998566
# 3       스포츠  0.823920 -1.000000  -1.000000  -0.641196   0.315615 -0.975365
# 4    라이프스타일 -0.255034 -0.275168  -0.255034  -0.295302  -0.355705 -1.005135
# 5   도서/참고자료  0.441558  0.480519   0.480519   0.363636   0.402597 -0.982796
# 6        금융 -1.000000  9.000000  16.000000  10.000000  20.000000 -2.000000
# 7       생산성  0.749117  0.939929   0.971731   0.621908   0.685512 -0.976177
# 8       데이트  0.610147  0.766355   0.766355   0.850467   1.018692 -0.992668
# 9    음악/오디오  0.406250  0.265625   0.406250  -0.015625  -0.156250 -0.942871
# 10       만화  7.000000 -1.000000  11.000000  -1.000000  -1.000000  6.000000
# 11   커뮤니케이션  0.639535  0.627907   0.616279   0.604651   1.023256 -0.992564

# %%
month = list()
for i in range(1,7):
  month.append(list(sales_playstore_20[str(i)+'월']))
genre_list = list(sales_playstore_20['genre'])
print(len(genre_list))
# Out:
# 12

# %%
sales_playstore_20_graph = pd.DataFrame()
for i in range(6):
  sales_playstore_20_fig = pd.DataFrame(genre_list,columns = ['genre'])
  sales_playstore_20_fig['value'] = month[i]
  sales_playstore_20_fig['month'] = str(i+1)+'월'
  sales_playstore_20_fig = sales_playstore_20_fig[['genre','month','value']]
  sales_playstore_20_graph = pd.concat([sales_playstore_20_graph,sales_playstore_20_fig], axis = 0)

sales_playstore_20_graph
# Out:
#      genre month     value
# 0       소셜    1월  0.559310
# 1       교육    1월  2.046154
# 2   엔터테인먼트    1월  0.230663
# 3      스포츠    1월  0.823920
# 4   라이프스타일    1월 -0.255034
# ..     ...   ...       ...
# 7      생산성    6월 -0.976177
# 8      데이트    6월 -0.992668
# 9   음악/오디오    6월 -0.942871
# 10      만화    6월  6.000000
# 11  커뮤니케이션    6월 -0.992564
#
# [72 rows x 3 columns]

# %%
df = sales_playstore_20_graph

fig = px.bar(df, x="genre", y="value", color="genre",
  animation_frame="month", animation_group="genre", range_y=[-5, 20])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="508d66fc-e0cc-449e-b0e5-dd34bb425989" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("508d66fc-e0cc-449e-b0e5-dd34bb425989")) {
#                     Plotly.newPlot(
#                         '508d66fc-e0cc-449e-b0e5-dd34bb425989',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc18c\uc15c"], "legendgroup": "genre=\uc18c\uc15c", "marker": {"color": "#636efa"}, "name": "genre=\uc18c\uc15c", "offsetgroup": "genre=\uc18c\uc15c", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc18c\uc15c"], "xaxis": "x", "y": [0.5593098490294753], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uad50\uc721"], "legendgroup": "genre=\uad50\uc721", "marker": {"color": "#EF553B"}, "name": "genre=\uad50\uc721", "offsetgroup": "genre=\uad50\uc721", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uad50\uc721"], "xaxis": "x", "y": [2.046153846153846], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "legendgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "marker": {"color": "#00cc96"}, "name": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "offsetgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "xaxis": "x", "y": [0.2306629834254144], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc2a4\ud3ec\uce20"], "legendgroup": "genre=\uc2a4\ud3ec\uce20", "marker": {"color": "#ab63fa"}, "name": "genre=\uc2a4\ud3ec\uce20", "offsetgroup": "genre=\uc2a4\ud3ec\uce20", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc2a4\ud3ec\uce20"], "xaxis": "x", "y": [0.823920265780731], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c"], "legendgroup": "genre=\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c", "marker": {"color": "#FFA15A"}, "name": "genre=\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c", "offsetgroup": "genre=\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c"], "xaxis": "x", "y": [-0.25503355704697983], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc"], "legendgroup": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "marker": {"color": "#19d3f3"}, "name": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "offsetgroup": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc"], "xaxis": "x", "y": [0.4415584415584415], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uae08\uc735"], "legendgroup": "genre=\uae08\uc735", "marker": {"color": "#FF6692"}, "name": "genre=\uae08\uc735", "offsetgroup": "genre=\uae08\uc735", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uae08\uc735"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc0dd\uc0b0\uc131"], "legendgroup": "genre=\uc0dd\uc0b0\uc131", "marker": {"color": "#B6E880"}, "name": "genre=\uc0dd\uc0b0\uc131", "offsetgroup": "genre=\uc0dd\uc0b0\uc131", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc0dd\uc0b0\uc131"], "xaxis": "x", "y": [0.7491166077738517], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlab ...
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "month="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1\uc6d4"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1\uc6d4", "method": "animate"}, {"args": [["2\uc6d4"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2\uc6d4", "method": "animate"}, {"args": [["3\uc6d4"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "3\uc6d4", "method": "animate"}, {"args": [["4\uc6d4"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "4\uc6d4", "method": "animate"}, {"args": [["5\uc6d4"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true,

# %%
appRank_free_appstore_19_df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
tmp = [i for i in list(appRank_free_appstore_19_df) if 'gen' in i]
free_a_gen = list(set(np.array(appRank_free_appstore_19_df[tmp]).reshape(len(tmp)*100,)))
free_a_gen_dic_19 = []
for i in tmp:
  free_a_gen_dic_tmp = {key: 0 for key in dict.fromkeys(free_a_gen).keys()}
  score = 100
  for j in appRank_free_appstore_19_df.dropna()[i]:
    free_a_gen_dic_tmp[j] = free_a_gen_dic_tmp[j]+score
    score -= 1
  free_a_gen_dic_19.append(free_a_gen_dic_tmp)

print(free_a_gen_dic_19)
# Out:
# [{nan: 0, 'Board': 0, '금융': 381, '시뮬레이션\n  (일 경과)': 0, 'Productivity': 0, '어드벤처': 80, 'Social Networking': 0, 'Entertainment': 66, '엔터테인먼트': 319, '커뮤니케이션': 139, '비즈니스': 29, 'Utilities': 0, 'Lifestyle': 0, '동영상 플레이어/편집기': 203, '아케이드': 178, '라이프스타일': 56, '여행 및 지역정보': 425, 'Navigation': 0, '쇼핑': 524, '도서/참고자료': 109, '캐주얼 게임': 0, '지도/내비게이션': 211, '보드': 0, '스포츠': 0, '롤플레잉\n  (일 경과)': 0, 'Simulation': 0, '부동산/홈 인테리어': 216, 'Games': 0, '소셜': 256, 'Finance': 0, 'Card': 0, '퍼즐': 0, '시뮬레이션': 56, '식음료': 147, '\n  (일 경과)\n-\n\n': 0, '사진': 119, 'Trivia': 0, '음악/오디오': 67, '퀴즈': 0, 'Food & Drink': 0, 'Family': 48, '퍼즐\n  (일 경과)': 0, '자동차 경주': 46, '액션': 161, 'Action': 58, '건강/운동': 20, '도구': 163, '전략': 0, '라이프스타일\n  (일 경과)': 0, '생산성': 54, '카지노': 0, '교육': 0, '롤플레잉': 448, '날씨': 0, 'Photo & Video': 99, '만화': 40, '비즈니스\n  (일 경과)': 55, 'Adventure': 0, 'Role Playing': 0, '뷰티': 24, '음악': 100, 'Puzzle': 0, '카드': 0}, {nan: 0, 'Board': 0, '금융': 550, '시뮬레이션\n  (일 경과)': 0, 'Productivity': 123, '어드벤처': 31, 'Social Networking': 0, 'Entertainment': 0, '엔터테인먼트': 210, '커뮤니케이션': 392, '비즈니스': 0, 'Utilities': 0, 'Lifestyle': 0, '동영상 플레이어/편집기': 219, '아케이드': 77, '라이프스타일': 18, '여행 및 지역정보': 428, 'Navigation': 0, '쇼핑': 428, '도서/참고자료': 0, '캐주얼 게임': 0, '지도/내비게이션': 330, '보드': 34, '스포츠': 0, '롤플레잉\n  (일 경과)': 0, 'Simulation': 0, '부동산/홈 인테리어': 136, 'Games': 0, '소셜': 237, 'Finance': 0, 'Card': 0, '퍼즐': 58, '시뮬레이션': 0, '식음료': 260, '\n  (일 경과)\n-\n\n': 0, '사진': 90, 'Trivia': 0, '음
 'Utilities': 0, 'Lifestyle': 0, '동영상 플레이어/편집기': 209, '아케이드': 82, '라이프스타일': 367, '여행 및 지역정보': 353, 'Navigation': 0, '쇼핑': 306, '도서/참고자료': 64, '캐주얼 게임': 0, '지도/내비게이션': 104, '보드': 86, '스포츠': 76, '롤플레잉\n  (일 경과)': 0, ...

# %%
col = []
for i in range(12):
  col.append('19_'+str(i+1))

free_appstore_19 = pd.DataFrame(free_a_gen_dic_19)
free_appstore_19 = free_appstore_19.T
free_appstore_19.columns = col
free_appstore_19 = free_appstore_19.drop([free_appstore_19.index[0]])
free_appstore_19.head()
# Out:
#                  19_1  19_2  19_3  19_4  19_5  ...  19_8  19_9  19_10  19_11  19_12
# Board               0     0     0     0   117  ...     0     0      0      0     33
# 금융                381   550   568   421   558  ...   377   394    763    454    489
# 시뮬레이션\n  (일 경과)     0     0     0     0     0  ...    94     0      0      0      0
# Productivity        0   123     0    75     0  ...     0     0      0      0      0
# 어드벤처               80    31     0    54     0  ...     0     0      0     40     81
#
# [5 rows x 12 columns]

# %%
free_a_standard_19 = free_appstore_19[['19_1','19_2','19_3','19_4','19_5','19_6','19_7','19_8','19_9']]
free_a_standard_19 = free_a_standard_19.reset_index()
free_a_standard_19 = free_a_standard_19.set_index('index')
free_a_standard_19.head()
# Out:
#                  19_1  19_2  19_3  19_4  19_5  19_6  19_7  19_8  19_9
# index
# Board               0     0     0     0   117     0     0     0     0
# 금융                381   550   568   421   558   402   240   377   394
# 시뮬레이션\n  (일 경과)     0     0     0     0     0     0     0    94     0
# Productivity        0   123     0    75     0     0     0     0     0
# 어드벤처               80    31     0    54     0    98     0     0     0

# %%
free_a_standard_19['average'] = 0.000
print(len(free_a_standard_19))
for i in range(24):
  total = 0
  for j in range(0,9):
    total += free_a_standard_19.iloc[i][j]
  free_a_standard_19['average'][i] = total/9

free_a_standard_19 = free_a_standard_19[['average']]
free_a_standard_19.head()
# Out:
# 62
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                     average
# index
# Board             13.000000
# 금융               432.333333
# 시뮬레이션\n  (일 경과)   10.444444
# Productivity      22.000000
# 어드벤처              29.222222

# %%
free_a_standard_19 = free_a_standard_19.reset_index()
genre = list(free_a_standard_19['index'])
free_a_standard_19 = free_a_standard_19.set_index('index')
free_a_standard_19.head()
# Out:
#                     average
# index
# Board             13.000000
# 금융               432.333333
# 시뮬레이션\n  (일 경과)   10.444444
# Productivity      22.000000
# 어드벤처              29.222222

# %%
appRank_free_appstore_20_df.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
tmp = [i for i in list(appRank_free_appstore_20_df) if 'gen' in i]
free_a_gen = list(set(np.array(appRank_free_appstore_20_df[tmp]).reshape(len(tmp)*100,)))
free_a_gen_dic_20 = []
for i in tmp:
  free_a_gen_dic_tmp = {key: 0 for key in dict.fromkeys(free_a_gen).keys()}
  score = 100
  for j in appRank_free_appstore_20_df.dropna()[i]:
    free_a_gen_dic_tmp[j] = free_a_gen_dic_tmp[j]+score
    score -= 1
  free_a_gen_dic_20.append(free_a_gen_dic_tmp)

print(free_a_gen_dic_20)
# Out:
# [{nan: 0, '금융': 707, 'Productivity': 0, '어드벤처': 52, '엔터테인먼트': 202, '커뮤니케이션': 295, '비즈니스': 59, 'Utilities': 0, 'Lifestyle': 0, '동영상 플레이어/편집기':
'Navigation': 53, '쇼핑': 334, '도서/참고자료': 83, '캐주얼 게임': 38, '지도/내비게이션': 96, '보드': 0, '스포츠': 0, '부동산/홈 인테리어': 82, '소셜': 219, '퍼즐': 0, '시뮬레이션': 0, '식음료': 142, '캐주얼 게임\n  (일 경과)': 62, '사진': 191, '음악/오디오': 141, '퀴즈': 0, '자동차 경주': 0, '액션': 112, '건강/운동': 30, '도구': 211, '전략': 96, '생산성': 223, '교육': 224, '롤플레잉': 93, 'Photo & Video': 0, '만화': 66, '비즈니스\n  (일 경과)': 0, '뷰티': 0, '음악': 0, '카드': 99}, {nan: 0, '금융': 397, 'Productivity': 0, '어드벤처': 0, '엔터테인먼트': 288, '커뮤니케이션': 277, '비즈니스': 157, 'Utilities': 0, 'Lifestyle': 0, '동영상 플레이어/편집기': 152, '뉴스/잡지': 0, '아케이드': 128, '여행 및 지역정보': 229, '라이프스타일': 194, 'Navigation': 0, '쇼핑': 591, '도서/참고자료': 94, '캐주얼 게임': 75, '지도/내비게이션': 198, '보드': 0, '스포츠': 0, '부동산/홈 인테리어': 112, '소셜': 291, '퍼즐': 0, '시뮬레이션': 35, '식음료': 171, '캐주얼 게임\n  (일 경과)': 0, '사진': 211, '음악/오디오': 190, '퀴즈': 0, '자동차 경주': 100, '액션': 67, '건강/운동': 30, '도구': 204, '전략': 99, '생산성': 102, '교육': 77, '롤플레잉': 172, 'Photo & Video': 0, '만화': 84, '비즈니스\n  (일 경과)': 0, '뷰티': 0, '음악': 0, '카드': 0}, {nan: 0, '금융': 439, 'Productivity': 0, '어드벤처': 0, '엔터테인먼트': 127, '커뮤니케이션': 182, '비즈니스': 176, 'Utilities': 0, 'Lifestyle': 28, '동영상 플레이어/편집기': 309, '뉴스/잡지': 0, '아케이드': 0, '여행 및 지역정보': 290, '라이프스타일': 146, 'Navigation': 56, '쇼핑': 628, '도서/참고자료': 94, '캐주얼 게임': 0, '지도/내비게이션': 29, '보드': 0, '스포츠': 87, '부동산/홈 인테리어': 142, '소셜': 256, '퍼즐': 251, '시뮬레이션': 0, '식음료': 295, '캐주얼 게임\n  (일 경과)': 0, '사진': 252, '음악/오디오': 145, '퀴즈': 0, '자동차 경주': 100, '액션': 47, '건강/운동': 0, '도구': 166, '전략': 31, '생산성': 186, '교육': 88, '롤플레잉': 116, 'Photo & Video': 0, '만화': 0, '비즈니스\n  (일 경과)': 59, '뷰티': 0, '음악': 0, '카드': 0}]

# %%
col = []
for i in range(6):
  col.append('20_'+str(i+1))

free_appstore_20 = pd.DataFrame(free_a_gen_dic_20)
free_appstore_20 = free_appstore_20.T
free_appstore_20.columns = col
free_appstore_20 = free_appstore_20.drop([free_appstore_20.index[0]])
free_appstore_20.head()
# Out:
#               20_1  20_2  20_3  20_4  20_5  20_6
# 금융             707   299   749   932   397   439
# Productivity     0     0    34    69     0     0
# 어드벤처            52    86     0     0     0     0
# 엔터테인먼트         202   158    97   149   288   127
# 커뮤니케이션         295   439   276   276   277   182

# %%
col = []
for i in range(1,7):
  col.append(str(i)+'월')

print(col)
# Out:
# ['1월', '2월', '3월', '4월', '5월', '6월']

# %%
free_appstore_20 = free_appstore_20.reset_index()
free_appstore_20.head()
# Out:
#           index  20_1  20_2  20_3  20_4  20_5  20_6
# 0            금융   707   299   749   932   397   439
# 1  Productivity     0     0    34    69     0     0
# 2          어드벤처    52    86     0     0     0     0
# 3        엔터테인먼트   202   158    97   149   288   127
# 4        커뮤니케이션   295   439   276   276   277   182

# %%
for i in range(len(col)):
  free_appstore_20[col[i]] = 0.000

for i in range(len(free_appstore_20)):
  base = free_appstore_20['index'][i]
  if base in genre:
    idx = genre.index(base)
    base = free_a_standard_19.iloc[idx]['average']
  else:
    base = 1.0
  for j in range(2, 8):
    if base == 0:
      value = 0.0
    else:
      value = (float(free_appstore_20.iloc[i][j]) - base) / base
    free_appstore_20[col[j-2]][i] = value

free_appstore_20.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           index  20_1  20_2  20_3  ...        3월        4월        5월        6월
# 0            금융   707   299   749  ...  1.155744 -0.081727  0.015420 -1.000713
# 1  Productivity     0     0    34  ...  2.136364 -1.000000 -1.000000 -1.045455
# 2          어드벤처    52    86     0  ... -1.000000 -1.000000 -1.000000 -0.933511
# 3        엔터테인먼트   202   158    97  ... -0.405322  0.149446 -0.493126 -1.001474
# 4        커뮤니케이션   295   439   276  ...  0.263479  0.268057 -0.166836 -0.995378
#
# [5 rows x 13 columns]

# %%
free_appstore_20 = free_appstore_20.set_index('index')
free_appstore_20 = free_appstore_20[['1월','2월','3월','4월','5월','6월']]
free_appstore_20 = free_appstore_20.reset_index()
free_appstore_20.columns = ['genre', '1월','2월','3월','4월','5월','6월']
free_appstore_20
# Out:
#                genre         1월        2월  ...        4월        5월         6월
# 0                 금융  -0.308404  0.732460  ... -0.081727  0.015420  -1.000713
# 1       Productivity  -1.000000  0.545455  ... -1.000000 -1.000000  -1.045455
# 2               어드벤처   1.942966 -1.000000  ... -1.000000 -1.000000  -0.933511
# 3             엔터테인먼트  -0.369401 -0.612860  ...  0.149446 -0.493126  -1.001474
# 4             커뮤니케이션   1.009664  0.263479  ...  0.268057 -0.166836  -0.995378
# 5               비즈니스   4.245856  4.867403  ...  2.903315  3.375691  -0.894440
# 6          Utilities   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 7          Lifestyle  -1.000000 -1.000000  ... -1.000000  6.636364  -1.272727
# 8       동영상 플레이어/편집기  -0.534483  0.192611  ... -0.326108  0.369951  -1.002370
# 9              뉴스/잡지  61.000000 -1.000000  ... -1.000000 -1.000000  60.000000
# 10              아케이드   0.210762 -1.000000  ...  0.291480 -1.000000  -0.997873
# 11         여행 및 지역정보  -1.000000 -0.771955  ... -0.406565 -0.248488  -1.002591
# 12            라이프스타일  -1.000000 -0.511482  ...  0.822547  0.371608  -1.009395
# 13        Navigation   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 14                쇼핑   0.215010 -0.032454  ...  0.198783  0.273834  -0.999564
# 15           도서/참고자료  -0.161209 -0.206549  ...  0.065491  0.065491  -1.001827
# 16            캐주얼 게임   0.807692  1.653846  ...  1.884615 -1.000000  -0.968935
# 17          지도/내비게이션  -1.000000 -0.646007  ...  0.061979 -0.844458  -1.005364
# 18                보드   1.373047  0.001953  ... -1.000000 -1.000000  -0.975864
# 19               스포츠   0.539823 -1.000000  ... -1.000000  1.309735  -0.985668
# 20        부동산/홈 인테리어   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 21                소셜   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 22                퍼즐   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 23             시뮬레이션   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 24               식음료   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 25  캐주얼 게임\n  (일 경과)  -1.000000 -1.000000  ... -1.000000 -1.000000  -2.000000
# 26                사진   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 27            음악/오디오   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 28                퀴즈   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 29            자동차 경주   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 30                액션   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 31             건강/운동   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 32                도구   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 33                전략   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 34               생산성   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 35                교육   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 36              롤플레잉   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 37     Photo & Video   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 38                만화   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 39    비즈니스\n  (일 경과)   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 40                뷰티   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 41                음악   0.000000  0.000000  ...  0.000000  0.000000   0.000000
# 42                카드   0.000000  0.000000  ...  0.000000  0.000000   0.000000
#
# [43 rows x 7 columns]

# %%
month = list()
for i in range(1,7):
  month.append(list(free_appstore_20[str(i)+'월']))

# %%
genre_list = list(free_appstore_20['genre'])

# %%
free_appstore_20_graph = pd.DataFrame()
for i in range(6):
  free_appstore_20_fig = pd.DataFrame(genre_list,columns = ['genre'])
  free_appstore_20_fig['value'] = month[i]
  free_appstore_20_fig['month'] = str(i+1)+'월'
  free_appstore_20_fig = free_appstore_20_fig[['genre','month','value']]
  free_appstore_20_graph = pd.concat([free_appstore_20_graph,free_appstore_20_fig], axis = 0)

free_appstore_20_graph
# Out:
#              genre month     value
# 0               금융    1월 -0.308404
# 1     Productivity    1월 -1.000000
# 2             어드벤처    1월  1.942966
# 3           엔터테인먼트    1월 -0.369401
# 4           커뮤니케이션    1월  1.009664
# ..             ...   ...       ...
# 38              만화    6월  0.000000
# 39  비즈니스\n  (일 경과)    6월  0.000000
# 40              뷰티    6월  0.000000
# 41              음악    6월  0.000000
# 42              카드    6월  0.000000
#
# [258 rows x 3 columns]

# %%
df = free_appstore_20_graph

fig = px.bar(df, x="genre", y="value", color="genre",
  animation_frame="month", animation_group="genre", range_y=[-5, 65])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fbd3c420-6995-4d11-8c42-8c6db4c699c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fbd3c420-6995-4d11-8c42-8c6db4c699c5")) {
#                     Plotly.newPlot(
#                         'fbd3c420-6995-4d11-8c42-8c6db4c699c5',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uae08\uc735"], "legendgroup": "genre=\uae08\uc735", "marker": {"color": "#636efa"}, "name": "genre=\uae08\uc735", "offsetgroup": "genre=\uae08\uc735", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uae08\uc735"], "xaxis": "x", "y": [-0.30840400925212025], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["Productivity"], "legendgroup": "genre=Productivity", "marker": {"color": "#EF553B"}, "name": "genre=Productivity", "offsetgroup": "genre=Productivity", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Productivity"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc5b4\ub4dc\ubca4\ucc98"], "legendgroup": "genre=\uc5b4\ub4dc\ubca4\ucc98", "marker": {"color": "#00cc96"}, "name": "genre=\uc5b4\ub4dc\ubca4\ucc98", "offsetgroup": "genre=\uc5b4\ub4dc\ubca4\ucc98", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc5b4\ub4dc\ubca4\ucc98"], "xaxis": "x", "y": [1.9429657794676807], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "legendgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "marker": {"color": "#ab63fa"}, "name": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "offsetgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "xaxis": "x", "y": [-0.3694013303769401], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ucee4\ubba4\ub2c8\ucf00\uc774\uc158"], "legendgroup": "genre=\ucee4\ubba4\ub2c8\ucf00\uc774\uc158", "marker": {"color": "#FFA15A"}, "name": "genre=\ucee4\ubba4\ub2c8\ucf00\uc774\uc158", "offsetgroup": "genre=\ucee4\ubba4\ub2c8\ucf00\uc774\uc158", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ucee4\ubba4\ub2c8\ucf00\uc774\uc158"], "xaxis": "x", "y": [1.0096642929806714], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ube44\uc988\ub2c8\uc2a4"], "legendgroup": "genre=\ube44\uc988\ub2c8\uc2a4", "marker": {"color": "#19d3f3"}, "name": "genre=\ube44\uc988\ub2c8\uc2a4", "offsetgroup": "genre=\ube44\uc988\ub2c8\uc2a4", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ube44\uc988\ub2c8\uc2a4"], "xaxis": "x", "y": [4.24585635359116], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["Utilities"], "legendgroup": "genre=Utilities", "marker": {"color": "#FF6692"}, "name": "genre=Utilities", "offsetgroup": "genre=Utilities", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Utilities"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["Lifestyle"], "legendgroup": "genre=Lifestyle", "marker": {"color": "#B6E880"}, "name": "genre=Lifestyle", "offsetgroup": "genre=Lifestyle", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Lifestyle"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub3d9\uc601\uc0c1 \ud50c\ub ...

# %%
appRank_pay_appstore_19_df.drop(['Unnamed: 0'], axis = 1, inplace= True)

# %%
tmp = [i for i in list(appRank_pay_appstore_19_df) if 'gen' in i]
pay_a_gen = list(set(np.array(appRank_pay_appstore_19_df[tmp]).reshape(len(tmp)*100,)))
pay_a_gen_dic_19 = []
for i in tmp:
  pay_a_gen_dic_tmp = {key: 0 for key in dict.fromkeys(pay_a_gen).keys()}
  score = 100
  for j in appRank_pay_appstore_19_df.dropna()[i]:
    pay_a_gen_dic_tmp[j] = pay_a_gen_dic_tmp[j]+score
    score -= 1
  pay_a_gen_dic_19.append(pay_a_gen_dic_tmp)

print(pay_a_gen_dic_19)
# Out:
# [{nan: 0, '금융': 0, 'Productivity': 74, '어드벤처': 193, 'Social Networking': 76, 'Entertainment': 47, '커뮤니케이션': 0, 'Books': 0, 'Utilities': 0, 'Lifestyle': 0, '아케이드': 91, '라이프스타일': 82, '도서/참고자료': 72, 'Music': 0, '캐주얼 게임': 0, '지도/내비게이션': 0, 'Racing': 0, '스포츠': 67, '보드': 133, 'Health & Fitness': 124, 'Simulation': 65, 'Finance': 82, '시뮬레이션': 248, '퍼즐': 194, 'Education': 61, 'Reference': 0, '사진': 403, '음악/오디오': 0, 'Family': 0, '자동차 경주': 0, '액션': 221, '의료\n  (일 경과)': 0, 'Action': 64, '도구': 73, '전략': 173, '생산성': 259, '교육': 91, 'Sports': 0, '롤플레잉': 271, 'Medical': 0, 'Photo & Video': 1122, 'Adventure': 0, 'Role Playing': 90, '음악': 159, 'Puzzle': 77, '카드': 60}, {nan: 0, '금융': 0, 'Productivity': 177, '어드벤처': 285, 'Social Networking': 79, 'Entertainment': 165, '커뮤니케이션': 0, 'Books': 0, 'Utilities': 0, 'Lifestyle': 68, '아케이드': 121, '라이프스타일': 0, '도서/참고자료': 101, 'Music': 51, '캐주얼 게임': 0, '지도/내비게이션': 0, 'Racing': 0, '스포츠': 60, '보드': 147, 'Health & Fitness': 72, 'Simulation': 0, 'Finance': 0, '시뮬레이션': 224, '퍼즐': 47, 'Education': 55, 'Reference': 0, '사진': 424, '음악/오디오': 0, 'Family': 0, '자동차 경주': 0, '액션': 61, '의료\n  (일 경과)': 0, 'Action': 0, '도구': 62, '전략': 82, '생산성': 264, '교육': 91, 'Sports': 37, '롤
 'Music': 39, '캐주얼 게임': 68, '지도/내비게이션': 0, 'Racing': 0, '스포츠': 98, '보드': 70, 'Health & Fitness': 29, 'Simulation': 32, 'Finance': 60, '시뮬레이션': 240, '퍼즐': 186, 'Education': 0, 'Reference': 0, '사진': 307, '음악/오디오': 41, 'Family': 0, '자동차 경주': 0, '액션': 0, '의료\n  (일 경과)': 0, 'Action': 0, '도구': 0, '전략': 512, '생산성': 180, '교육': 59, 'Sports': 0, '롤플레잉': 268, 'Medical': 0, 'Photo & Video': 1104, 'Adventure': 142, 'Role Playing': 61, '음악': 162, 'Puzzle': 34, '카드': 0}, {nan: 0, '금융': 52, 'Productivity': 141, ' ...

# %%
col = []
for i in range(12):
  col.append('19_'+str(i+1))

pay_appstore_19 = pd.DataFrame(pay_a_gen_dic_19)
pay_appstore_19 = pay_appstore_19.T
pay_appstore_19.columns = col
pay_appstore_19 = pay_appstore_19.drop([pay_appstore_19.index[0]])
pay_appstore_19.head()
# Out:
#                    19_1  19_2  19_3  19_4  ...  19_9  19_10  19_11  19_12
# 금융                    0     0     0    58  ...    79     74      0     74
# Productivity         74   177   120    95  ...   312    253    231    171
# 어드벤처                193   285   479   282  ...   259    182    155    240
# Social Networking    76    79     0     0  ...    68     46     28      0
# Entertainment        47   165   125   171  ...   183     28     80     84
#
# [5 rows x 12 columns]

# %%
pay_a_standard_19 = pay_appstore_19[['19_1','19_2','19_3','19_4','19_5','19_6','19_7','19_8','19_9']]
pay_a_standard_19 = pay_a_standard_19.reset_index()
pay_a_standard_19 = pay_a_standard_19.set_index('index')
pay_a_standard_19.head()
# Out:
#                    19_1  19_2  19_3  19_4  19_5  19_6  19_7  19_8  19_9
# index
# 금융                    0     0     0    58     0     0    52    67    79
# Productivity         74   177   120    95   228   198   141   268   312
# 어드벤처                193   285   479   282   177   380   276   319   259
# Social Networking    76    79     0     0    74     0    76    54    68
# Entertainment        47   165   125   171   170     0    50    74   183

# %%
pay_a_standard_19['average'] = 0.000
for i in range(len(pay_a_standard_19)):
  total = 0
  for j in range(0,9):
    total += pay_a_standard_19.iloc[i][j]
  pay_a_standard_19['average'][i] = total/9

pay_a_standard_19 = pay_a_standard_19[['average']]
pay_a_standard_19.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       average
# index
# 금융                  28.444444
# Productivity       179.222222
# 어드벤처               294.444444
# Social Networking   47.444444
# Entertainment      109.444444

# %%
pay_a_standard_19 = pay_a_standard_19.reset_index()
genre = list(pay_a_standard_19['index'])
pay_a_standard_19 = pay_a_standard_19.set_index('index')
pay_a_standard_19.head()
# Out:
#                       average
# index
# 금융                  28.444444
# Productivity       179.222222
# 어드벤처               294.444444
# Social Networking   47.444444
# Entertainment      109.444444

# %%
appRank_pay_appstore_20_df.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
tmp = [i for i in list(appRank_pay_appstore_20_df) if 'gen' in i]
pay_a_gen = list(set(np.array(appRank_pay_appstore_20_df[tmp]).reshape(len(tmp)*100,)))
pay_a_gen_dic_20 = []
for i in tmp:
  pay_a_gen_dic_tmp = {key: 0 for key in dict.fromkeys(pay_a_gen).keys()}
  score = 100
  for j in appRank_pay_appstore_20_df.dropna()[i]:
    pay_a_gen_dic_tmp[j] = pay_a_gen_dic_tmp[j]+score
    score -= 1
  pay_a_gen_dic_20.append(pay_a_gen_dic_tmp)

print(pay_a_gen_dic_20)
# Out:
# [{nan: 0, '금융': 81, 'Productivity': 345, '어드벤처': 434, 'Social Networking': 0, 'Entertainment': 141, '커뮤니케이션': 0, 'Books': 61, 'Utilities': 0, 'Lifestyle': 69, '아케이드': 189, '라이프스타일': 0, '도서/참고자료': 0, 'Music': 54, '캐주얼 게임': 59, '스포츠': 93, '보드': 66, 'Health & Fitness': 67, 'Strategy': 0, 'Finance': 116, 'Arcade': 0, '퍼즐': 0, '시뮬레이션': 206, 'Education': 159, '사진': 351, 'Family': 0, '자동차 경주': 46, '액션': 0, 'Action': 62, '전략': 122, '생산성': 95, '교육': 80, '롤플레잉': 176, 'Photo & Video': 639, 'Adventure': 56, 'Role Playing': 0, '음악': 248, 'Puzzle': 0, '카드': 0}, {nan: 0, '금융': 74, 'Productivity': 317, '어드벤처': 307, 'Social Networking': 47, 'Entertainment': 0, '커뮤니케이션': 83, 'Books': 0, 'Utilities': 0, 'Lifestyle': 125, '아케이드': 134, '라이프스타일': 0, '도서/참고자료': 0, 'Music': 0, '캐주얼 게임': 0, '스포츠': 88, '보드': 135, 'Health & Fitness': 152, 'Strategy': 0, 'Finance': 0, 'Arcade': 0, '퍼즐': 58, '시뮬레이션': 305, 'Education': 62, '사진': 330, 'Family': 0, '자동차 경주': 0, '액션': 60, 'Action': 151, '전략': 100, '생산성': 70, '교육': 0, '롤플레잉': 201, 'Photo & Video': 817, 'Adventure': 99, 'Role Playing': 0, '음악': 300, 'Puzzle': 0, '카드': 0}, {nan: 0, '금융': 79, 'Productivity': 445, '어드벤처': 364, 'Social Networking': 52, 'Entertainment': 77, '커뮤니케이션': 65, 'Books': 51, 'Utilities': 60, 'Lifestyle': 58, '아케이드': 0, '라이프스타일': 57, '도서/참고자료': 49, 'Music': 0, '캐주얼 게임': 0, '스포츠': 167, '보드': 138, 'Health & Fitness': 154, 'Strategy': 0, 'Finance': 0, 'Arcade': 0, '퍼즐': 206, '시뮬레이션': 259, 'Education': 0, '사진': 379, 'Family': 0, '자동차 경주': 0, '액션': 0, 'Action': 0, '전략': 156, '생산성': 96, '교육': 124, '롤플레잉': 62, 'Photo & Video': 632, 'Adventure': 187, 'Role Playing': 0, '음악': 98, 'Puzzle': 0, '카드': 0}, {nan: 0, '금융': 0, 'Productivity': 332, '어드벤처': 72, 'Social Networking': 0, 'Entertainment': 136, '커뮤니케이션': 82, 'Books': 49, 'Utilities': 0, 'Lifestyle': 46, '아케이드': 139, '라이프스타일': 0, '도서/참고자료': 87, 'Music': 50, '캐주얼 게임': 0, '스포츠': 92, '보드': 122, 'Health & Fitness': 0, 'Strategy': 71, 'Finance': 128, 'Arcade': 0, '퍼즐': 115, '시뮬레이션': 377, 'Education': 132, '사진': 160, 'Family': 0, '자동차 경주': 0, '액션': 0, 'Action': 63, '전략': 153, '생산성': 183, '교육': 47, '롤플레잉': 243, 'Photo & Video': 882, 'Adventure': 76, 'Role Playing': 0, '음악': 94, 'Puzzle': 0, '카드': 84}, {nan: 0, '금융': 81, 'Productivity': 227, '어드벤처': 384, 'Social Networking': 0, 'Entertainment': 0, '커뮤니케이션': 69, 'Books': 54, 'Utilities': 63, 'Lifestyle': 0, '아케이드': 76, '라이프스타일': 0, '도서/참고자료': 88, 'Music': 55, '캐주얼 게임': 0, '스포츠': 90, '보드': 0, 'Health & Fitness': 75, 'Strategy': 0, 'Finance': 49, 'Arcade': 47, '퍼즐': 61, '시뮬레이션': 154, 'Education': 52, '사진': 93, 'Family': 0, '자동차 경주': 0, '액션': 94, 'Action': 0, '전략': 126, '생산성': 185, '교육': 0, '롤플레잉': 410, 'Photo & Video': 1015, 'Adventure': 218, 'Role Playing': 72, '음악': 98, 'Puzzle': 79, '카드': 0}, {nan: 0, '금융': 77, 'Productivity': 276, '어드벤처': 547, 'Social Networking': 0, 'Entertainment': 86, '커뮤니케이션': 79, 'Books': 0, 'Utilities': 135, 'Lifestyle': 55, '아케이드': 85, '라이프스타일': 112, '도서/참고자료': 94, 'Music': 0, '캐주얼 게임': 0, '스포츠': 148, '보드': 64, 'Health & Fitness': 73, 'Strategy': 0, 'Finance': 111, 'Arcade': 0, '퍼즐': 100, '시뮬레이션': 166, 'Education': 69, '사진': 162, 'Family': 0, '자동차 경주': 0, '액션': 0, 'Action': 54, '전략': 199, '생산성': 99, '교육': 61, '롤플레잉': 188, 'Photo & Video': 796, 'Adventure': 0, 'Role Playing': 0, '음악': 179, 'Puzzle': 0, '카드': 0}]

# %%
col = []
for i in range(6):
  col.append('20_'+str(i+1))

pay_appstore_20 = pd.DataFrame(pay_a_gen_dic_20)
pay_appstore_20 = pay_appstore_20.T
pay_appstore_20.columns = col
pay_appstore_20 = pay_appstore_20.drop([pay_appstore_20.index[0]])
pay_appstore_20.head()
# Out:
#                    20_1  20_2  20_3  20_4  20_5  20_6
# 금융                   81    74    79     0    81    77
# Productivity        345   317   445   332   227   276
# 어드벤처                434   307   364    72   384   547
# Social Networking     0    47    52     0     0     0
# Entertainment       141     0    77   136     0    86

# %%
col = []
for i in range(1,7):
  col.append(str(i)+'월')

print(col)
# Out:
# ['1월', '2월', '3월', '4월', '5월', '6월']

# %%
pay_appstore_20 = pay_appstore_20.reset_index()
pay_appstore_20.head()
# Out:
#                index  20_1  20_2  20_3  20_4  20_5  20_6
# 0                 금융    81    74    79     0    81    77
# 1       Productivity   345   317   445   332   227   276
# 2               어드벤처   434   307   364    72   384   547
# 3  Social Networking     0    47    52     0     0     0
# 4      Entertainment   141     0    77   136     0    86

# %%
for i in range(len(col)):
  pay_appstore_20[col[i]] = 0.000

for i in range(len(pay_appstore_20)):
  base = pay_appstore_20['index'][i]
  if base in genre:
    idx = genre.index(base)
    base = pay_a_standard_19.iloc[idx]['average']
  else:
    base = 1.0
  for j in range(2, 8):
    if base == 0:
      value = 0.0
    else:
      value = (float(pay_appstore_20.iloc[i][j]) - base) / base
    pay_appstore_20[col[j-2]][i] = value

pay_appstore_20.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 교육                -1.000000  0.636364  -0.379765  -1.000000 -0.195015 -1.013196
# 롤플레잉              -0.145489 -0.736419   0.033066   0.743033 -0.200756 -1.000619
# Photo & Video     -0.324235 -0.477254  -0.270471  -0.160463 -0.341605 -1.000268
# Adventure          0.080000  1.040000  -0.170909   1.378182 -1.000000 -0.999127
# Role Playing      -1.000000 -1.000000  -1.000000   0.957704 -1.000000 -1.027190
# 음악                 1.404274 -0.214604  -0.246661  -0.214604  0.434550 -0.988746
# Puzzle            -1.000000 -1.000000  -1.000000   0.751232 -1.000000 -1.022167
# 카드                -1.000000 -1.000000   0.270588  -1.000000 -1.000000 -1.015126

# %%
pay_appstore_20 = pay_appstore_20.reset_index()

# %%
month = list()
for i in range(1,7):
  month.append(list(pay_appstore_20[str(i)+'월']))

# %%
genre_list = list(pay_appstore_20['index'])

# %%
pay_appstore_20_graph = pd.DataFrame()
for i in range(6):
  pay_appstore_20_fig = pd.DataFrame(genre_list,columns = ['genre'])
  pay_appstore_20_fig['value'] = month[i]
  pay_appstore_20_fig['month'] = str(i+1)+'월'
  pay_appstore_20_fig = pay_appstore_20_fig[['genre','month','value']]
  pay_appstore_20_graph = pd.concat([pay_appstore_20_graph,pay_appstore_20_fig], axis = 0)

pay_appstore_20_graph
# Out:
#                 genre month     value
# 0                  금융    1월  1.601563
# 1        Productivity    1월  0.768754
# 2                어드벤처    1월  0.042642
# 3   Social Networking    1월 -0.009368
# 4       Entertainment    1월 -1.000000
# ..                ...   ...       ...
# 33          Adventure    6월 -0.999127
# 34       Role Playing    6월 -1.027190
# 35                 음악    6월 -0.988746
# 36             Puzzle    6월 -1.022167
# 37                 카드    6월 -1.015126
#
# [228 rows x 3 columns]

# %%
df = pay_appstore_20_graph

fig = px.bar(df, x="genre", y="value", color="genre",
  animation_frame="month", animation_group="genre", range_y=[-5, 22])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c099ed75-37e4-413f-bac3-abf1f6a9f491" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c099ed75-37e4-413f-bac3-abf1f6a9f491")) {
#                     Plotly.newPlot(
#                         'c099ed75-37e4-413f-bac3-abf1f6a9f491',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uae08\uc735"], "legendgroup": "genre=\uae08\uc735", "marker": {"color": "#636efa"}, "name": "genre=\uae08\uc735", "offsetgroup": "genre=\uae08\uc735", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uae08\uc735"], "xaxis": "x", "y": [1.6015625000000002], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["Productivity"], "legendgroup": "genre=Productivity", "marker": {"color": "#EF553B"}, "name": "genre=Productivity", "offsetgroup": "genre=Productivity", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Productivity"], "xaxis": "x", "y": [0.7687538747675139], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc5b4\ub4dc\ubca4\ucc98"], "legendgroup": "genre=\uc5b4\ub4dc\ubca4\ucc98", "marker": {"color": "#00cc96"}, "name": "genre=\uc5b4\ub4dc\ubca4\ucc98", "offsetgroup": "genre=\uc5b4\ub4dc\ubca4\ucc98", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc5b4\ub4dc\ubca4\ucc98"], "xaxis": "x", "y": [0.04264150943396222], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["Social Networking"], "legendgroup": "genre=Social Networking", "marker": {"color": "#ab63fa"}, "name": "genre=Social Networking", "offsetgroup": "genre=Social Networking", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Social Networking"], "xaxis": "x", "y": [-0.009367681498829007], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["Entertainment"], "legendgroup": "genre=Entertainment", "marker": {"color": "#FFA15A"}, "name": "genre=Entertainment", "offsetgroup": "genre=Entertainment", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Entertainment"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ucee4\ubba4\ub2c8\ucf00\uc774\uc158"], "legendgroup": "genre=\ucee4\ubba4\ub2c8\ucf00\uc774\uc158", "marker": {"color": "#19d3f3"}, "name": "genre=\ucee4\ubba4\ub2c8\ucf00\uc774\uc158", "offsetgroup": "genre=\ucee4\ubba4\ub2c8\ucf00\uc774\uc158", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ucee4\ubba4\ub2c8\ucf00\uc774\uc158"], "xaxis": "x", "y": [8.3375], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["Books"], "legendgroup": "genre=Books", "marker": {"color": "#FF6692"}, "name": "genre=Books", "offsetgroup": "genre=Books", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Books"], "xaxis": "x", "y": [0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["Utilities"], "legendgroup": "genre=Utilities", "marker": {"color": "#B6E880"}, "name": "genre=Utilities", "offsetgroup": "genre=Utilities", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Utilities"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["Lifestyle"], "legendgroup": "genre=Lifestyle", "marker": {"color": "#FF97FF"}, "name": "genre=Lifestyle", "offsetgroup": "genre=Lifestyle", "orientation": "v", "showlegend": true, "textposition": "auto", "ty ...

# %%
appRank_sales_appstore_19_df.drop(['Unnamed: 0'],axis=1,inplace= True)

# %%
tmp = [i for i in list(appRank_sales_appstore_19_df) if 'gen' in i]
sales_a_gen = list(set(np.array(appRank_sales_appstore_19_df[tmp]).reshape(len(tmp)*100,)))
sales_a_gen_dic_19 = []
for i in tmp:
  sales_a_gen_dic_tmp = {key: 0 for key in dict.fromkeys(sales_a_gen).keys()}
  score = 100
  for j in appRank_sales_appstore_19_df.dropna()[i]:
    sales_a_gen_dic_tmp[j] = sales_a_gen_dic_tmp[j]+score
    score -= 1
  sales_a_gen_dic_19.append(sales_a_gen_dic_tmp)

# %%
col = []
for i in range(12):
  col.append('19_'+str(i+1))

sales_appstore_19 = pd.DataFrame(sales_a_gen_dic_19)
sales_appstore_19 = sales_appstore_19.T
sales_appstore_19.columns = col
sales_appstore_19 = sales_appstore_19.drop([sales_appstore_19.index[0]])
sales_appstore_19.head()
# Out:
#                    19_1  19_2  19_3  19_4  ...  19_9  19_10  19_11  19_12
# 어드벤처                 60    74    37    77  ...    52     43      4     11
# Social Networking     3     3    21    11  ...     0      0      0      0
# Entertainment        47     0     0     0  ...     0      0      0      0
# 커뮤니케이션              151   162   156   160  ...   163    154    157    172
# 엔터테인먼트              279   274   236   299  ...   330    260    305    352
#
# [5 rows x 12 columns]

# %%
sales_appstore_19 = sales_appstore_19.reset_index()
sales_appstore_19 = sales_appstore_19.set_index('index')
sales_appstore_19.head()
# Out:
#                    19_1  19_2  19_3  19_4  ...  19_9  19_10  19_11  19_12
# index                                      ...
# 어드벤처                 60    74    37    77  ...    52     43      4     11
# Social Networking     3     3    21    11  ...     0      0      0      0
# Entertainment        47     0     0     0  ...     0      0      0      0
# 커뮤니케이션              151   162   156   160  ...   163    154    157    172
# 엔터테인먼트              279   274   236   299  ...   330    260    305    352
#
# [5 rows x 12 columns]

# %%
sales_appstore_19['average'] = 0.000

for i in range(len(sales_appstore_19)):
  total = 0
  for j in range(12):
    total += sales_appstore_19.iloc[i][j]
  sales_appstore_19['average'][i] = total/9

sales_appstore_19 = sales_appstore_19[['average']]
sales_appstore_19.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       average
# index
# 어드벤처                71.888889
# Social Networking   10.222222
# Entertainment        5.222222
# 커뮤니케이션             217.444444
# 엔터테인먼트             370.888889

# %%
sales_appstore_19 = sales_appstore_19.reset_index()
genre = list(sales_appstore_19['index'])
sales_appstore_19 = sales_appstore_19.set_index('index')
sales_appstore_19.head()
# Out:
#                       average
# index
# 어드벤처                71.888889
# Social Networking   10.222222
# Entertainment        5.222222
# 커뮤니케이션             217.444444
# 엔터테인먼트             370.888889

# %%
appRank_sales_appstore_20_df.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
tmp = [i for i in list(appRank_sales_appstore_20_df) if 'gen' in i]
sales_a_gen = list(set(np.array(appRank_sales_appstore_20_df[tmp]).reshape(len(tmp)*100,)))
sales_a_gen_dic_20 = []
for i in tmp:
  sales_a_gen_dic_tmp = {key: 0 for key in dict.fromkeys(sales_a_gen).keys()}
  score = 100
  for j in appRank_sales_appstore_20_df.dropna()[i]:
    sales_a_gen_dic_tmp[j] = sales_a_gen_dic_tmp[j]+score
    score -= 1
  sales_a_gen_dic_20.append(sales_a_gen_dic_tmp)

# %%
col = []
for i in range(6):
  col.append('20_'+str(i+1))

sales_appstore_20 = pd.DataFrame(sales_a_gen_dic_20)
sales_appstore_20 = sales_appstore_20.T
sales_appstore_20.columns = col
sales_appstore_20 = sales_appstore_20.drop([sales_appstore_20.index[0]])
sales_appstore_20.head()
# Out:
#               20_1  20_2  20_3  20_4  20_5  20_6
# 어드벤처            26    12    20   115    99    60
# 커뮤니케이션         163   159   176   140   167   184
# 엔터테인먼트         300   279   295   291   323   311
# 동영상 플레이어/편집기   129   144   161   122   143   137
# 아케이드           122   136    94   127    85    70

# %%
col = []
for i in range(1,7):
  col.append(str(i)+'월')

print(col)
# Out:
# ['1월', '2월', '3월', '4월', '5월', '6월']

# %%
sales_appstore_20 = sales_appstore_20.reset_index()

# %%
for i in range(len(col)):
  sales_appstore_20[col[i]] = 0.000

for i in range(len(sales_appstore_20)):
  base = sales_appstore_20['index'][i]
  if base in genre:
    idx = genre.index(base)
    base = sales_appstore_19.iloc[idx]['average']
  else:
    base = 1.0
  for j in range(2, 8):
    if base == 0:
      value = 0.0
    else:
      value = (float(sales_appstore_20.iloc[i][j]) - base) / base
    sales_appstore_20[col[j-2]][i] = value

sales_appstore_20.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           index  20_1  20_2  20_3  ...        3월        4월        5월        6월
# 0          어드벤처    26    12    20  ...  0.599691  0.377125 -0.165379 -1.011588
# 1        커뮤니케이션   163   159   176  ... -0.356157 -0.231988 -0.153807 -1.001236
# 2        엔터테인먼트   300   279   295  ... -0.215398 -0.129119 -0.161474 -1.000668
# 3  동영상 플레이어/편집기   129   144   161  ... -0.163747 -0.019802 -0.060929 -1.000089
# 4          아케이드   122   136    94  ...  0.111868 -0.255837 -0.387160 -0.998331
#
# [5 rows x 13 columns]

# %%
sales_appstore_20 = sales_appstore_20.set_index('index')
sales_appstore_20 = sales_appstore_20[['1월','2월','3월','4월','5월','6월']]
sales_appstore_20 = sales_appstore_20.reset_index()
sales_appstore_20
# Out:
#            index         1월        2월        3월         4월         5월        6월
# 0           어드벤처  -0.833076 -0.721793  0.599691   0.377125  -0.165379 -1.011588
# 1         커뮤니케이션  -0.268779 -0.190598 -0.356157  -0.231988  -0.153807 -1.001236
# 2         엔터테인먼트  -0.247753 -0.204614 -0.215398  -0.129119  -0.161474 -1.000668
# 3   동영상 플레이어/편집기  -0.012947  0.103580 -0.163747  -0.019802  -0.060929 -1.000089
# 4           아케이드   0.190661 -0.177043  0.111868  -0.255837  -0.387160 -0.998331
# 5         라이프스타일  -0.616114 -1.000000 -0.733412  -0.594787  -0.626777 -1.006570
# 6        도서/참고자료  -0.281690 -0.278169 -0.295775  -0.281690  -0.274648 -1.000992
# 7         캐주얼 게임  -0.053834 -0.341798 -0.186389  -0.552057  -0.245810 -1.000246
# 8            스포츠  -0.374034 -0.315611 -0.643895  -0.463060  -0.073570 -1.001041
# 9             보드  -0.162376 -0.456436 -0.483168  -0.331683  -0.741584 -1.001447
# 10            소셜  -0.294355 -0.084677 -0.350806  -0.044355  -0.120968 -1.001187
# 11         시뮬레이션   0.889580  0.707621 -0.748056   0.609642   0.245723 -0.987549
# 12            퍼즐  -0.409524 -0.704762 -0.942857  -0.857143  -0.904762 -1.003900
# 13            사진  -1.000000 -1.000000  4.307692  -1.000000   5.000000 -1.230769
# 14        음악/오디오  -0.210162 -0.147806 -0.168591  -0.196305  -0.383372 -1.000728
# 15        자동차 경주  -1.000000 -1.000000 -1.000000   7.181818   7.181818 -1.081818
# 16            액션  -0.290448 -0.483775 -0.276051  -0.395338  -0.578382 -1.000597
# 17           데이트  -0.632044 -0.283978 -0.502762  -0.602210  -0.164641 -1.006286
# 18            전략  -0.235062  0.154361 -0.044986  -0.250515  -0.123798 -1.000363
# 19           생산성  20.214286 -1.000000 -1.000000  -1.000000  -1.000000  5.497449
# 20           카지노   0.065789 -0.171053  0.444737  -0.265789  -0.644737 -0.998442
# 21            교육  -1.000000 -1.000000 -1.000000   3.680000  -1.000000 -1.360000
# 22          롤플레잉  -0.255003 -0.286270 -0.199138  -0.234992  -0.253752 -1.000106
# 23            만화  -0.216732 -0.191465 -0.272319  -0.186412  -0.226839 -1.001095
# 24            음악  -1.000000 -1.000000  1.259912  -1.000000  -0.246696 -1.039648
# 25  전략\n  (일 경과)  -1.000000 -1.000000 -1.000000  68.000000  75.500000 -2.500000
# 26            카드  -0.881406 -0.604685 -1.000000  -0.920937  -1.000000 -1.011614

# %%
sales_appstore_20.columns = ['genre', '1월','2월','3월','4월','5월','6월']

# %%
month = list()
for i in range(1,7):
  month.append(list(sales_appstore_20[str(i)+'월']))
genre_list = list(sales_appstore_20['genre'])
print(len(genre_list))
# Out:
# 27

# %%
sales_appstore_20_graph = pd.DataFrame()
for i in range(6):
  sales_appstore_20_fig = pd.DataFrame(genre_list,columns = ['genre'])
  sales_appstore_20_fig['value'] = month[i]
  sales_appstore_20_fig['month'] = str(i+1)+'월'
  sales_appstore_20_fig = sales_appstore_20_fig[['genre','month','value']]
  sales_appstore_20_graph = pd.concat([sales_appstore_20_graph,sales_appstore_20_fig], axis = 0)

sales_appstore_20_graph
# Out:
#            genre month     value
# 0           어드벤처    1월 -0.833076
# 1         커뮤니케이션    1월 -0.268779
# 2         엔터테인먼트    1월 -0.247753
# 3   동영상 플레이어/편집기    1월 -0.012947
# 4           아케이드    1월  0.190661
# ..           ...   ...       ...
# 22          롤플레잉    6월 -1.000106
# 23            만화    6월 -1.001095
# 24            음악    6월 -1.039648
# 25  전략\n  (일 경과)    6월 -2.500000
# 26            카드    6월 -1.011614
#
# [162 rows x 3 columns]

# %%
df = sales_appstore_20_graph

fig = px.bar(df, x="genre", y="value", color="genre",
  animation_frame="month", animation_group="genre", range_y=[-5, 20])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="30b707ff-eee9-479a-862a-2c9a54668dc8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("30b707ff-eee9-479a-862a-2c9a54668dc8")) {
#                     Plotly.newPlot(
#                         '30b707ff-eee9-479a-862a-2c9a54668dc8',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc5b4\ub4dc\ubca4\ucc98"], "legendgroup": "genre=\uc5b4\ub4dc\ubca4\ucc98", "marker": {"color": "#636efa"}, "name": "genre=\uc5b4\ub4dc\ubca4\ucc98", "offsetgroup": "genre=\uc5b4\ub4dc\ubca4\ucc98", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc5b4\ub4dc\ubca4\ucc98"], "xaxis": "x", "y": [-0.8330757341576507], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ucee4\ubba4\ub2c8\ucf00\uc774\uc158"], "legendgroup": "genre=\ucee4\ubba4\ub2c8\ucf00\uc774\uc158", "marker": {"color": "#EF553B"}, "name": "genre=\ucee4\ubba4\ub2c8\ucf00\uc774\uc158", "offsetgroup": "genre=\ucee4\ubba4\ub2c8\ucf00\uc774\uc158", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ucee4\ubba4\ub2c8\ucf00\uc774\uc158"], "xaxis": "x", "y": [-0.2687787429739397], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "legendgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "marker": {"color": "#00cc96"}, "name": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "offsetgroup": "genre=\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc5d4\ud130\ud14c\uc778\uba3c\ud2b8"], "xaxis": "x", "y": [-0.24775314559616543], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub3d9\uc601\uc0c1 \ud50c\ub808\uc774\uc5b4/\ud3b8\uc9d1\uae30"], "legendgroup": "genre=\ub3d9\uc601\uc0c1 \ud50c\ub808\uc774\uc5b4/\ud3b8\uc9d1\uae30", "marker": {"color": "#ab63fa"}, "name": "genre=\ub3d9\uc601\uc0c1 \ud50c\ub808\uc774\uc5b4/\ud3b8\uc9d1\uae30", "offsetgroup": "genre=\ub3d9\uc601\uc0c1 \ud50c\ub808\uc774\uc5b4/\ud3b8\uc9d1\uae30", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub3d9\uc601\uc0c1 \ud50c\ub808\uc774\uc5b4/\ud3b8\uc9d1\uae30"], "xaxis": "x", "y": [-0.012947448591012926], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\uc544\ucf00\uc774\ub4dc"], "legendgroup": "genre=\uc544\ucf00\uc774\ub4dc", "marker": {"color": "#FFA15A"}, "name": "genre=\uc544\ucf00\uc774\ub4dc", "offsetgroup": "genre=\uc544\ucf00\uc774\ub4dc", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc544\ucf00\uc774\ub4dc"], "xaxis": "x", "y": [0.19066147859922172], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c"], "legendgroup": "genre=\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c", "marker": {"color": "#19d3f3"}, "name": "genre=\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c", "offsetgroup": "genre=\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub77c\uc774\ud504\uc2a4\ud0c0\uc77c"], "xaxis": "x", "y": [-0.6161137440758293], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "genre=%{x}<br>month=1\uc6d4<br>value=%{y}", "ids": ["\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc"], "legendgroup": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "marker": {"color": "#FF6692"}, "name": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "offsetgroup": "genre=\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub3c4\uc11c/\ucc38\uace0\uc790\ub8cc"], "xaxis": "x", "y": [-0.28169014084507044], "yaxis": "y"}, {"alignmentgroup": "Tr ...
