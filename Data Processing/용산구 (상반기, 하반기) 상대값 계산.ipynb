# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ### csv_read

# %%
card_01 = pd.read_csv("card_202001.csv")
card_02 = pd.read_csv("card_202002.csv")
card_03 = pd.read_csv("card_202003.csv")
card_04 = pd.read_csv("card_202004.csv")
card_05 = pd.read_csv("card_202005.csv")
card_06 = pd.read_csv("card_202006.csv")

card_01.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200104   1174066000      성내3동                  7041
# 1      20200104   1174066000      성내3동                  7022
# 2      20200104   1174066000      성내3동                  7021
# 3      20200104   1174066000      성내3동                  7020
# 4      20200104   1174066000      성내3동                  6110
#
#   mrhst_induty_cl_nm  selng_cascnt     salamt
# 0                 약국           463  5843230.0
# 1               치과의원            33  7835550.0
# 2                한의원            53  4589800.0
# 3                 의원           339  9267240.0
# 4              자동차정비            19  4441000.0

# %%
adstrd=pd.read_csv('adstrd_master.csv')
adstrd['adstrd_code']=adstrd['adstrd_code'].astype(str)
adstrd['exp']=adstrd['adstrd_code'].apply(lambda x:x[:5])
adstrd['total_adstrd']=adstrd['brtc_nm']+' '+adstrd['signgu_nm']

adstrd_name=adstrd[['exp','total_adstrd']]
adstrd_name=adstrd_name.drop_duplicates(['exp'],keep='first')
adstrd_name=adstrd_name.reset_index()
adstrd_name=adstrd_name.drop(['index'],axis=1)
adstrd_name_seoul = adstrd_name[0:25]
adstrd_name_seoul
# Out:
#       exp total_adstrd
# 0   11110    서울특별시 종로구
# 1   11140     서울특별시 중구
# 2   11170    서울특별시 용산구
# 3   11200    서울특별시 성동구
# 4   11215    서울특별시 광진구
# 5   11230   서울특별시 동대문구
# 6   11260    서울특별시 중랑구
# 7   11290    서울특별시 성북구
# 8   11305    서울특별시 강북구
# 9   11320    서울특별시 도봉구
# 10  11350    서울특별시 노원구
# 11  11380    서울특별시 은평구
# 12  11410   서울특별시 서대문구
# 13  11440    서울특별시 마포구
# 14  11470    서울특별시 양천구
# 15  11500    서울특별시 강서구
# 16  11530    서울특별시 구로구
# 17  11545    서울특별시 금천구
# 18  11560   서울특별시 영등포구
# 19  11590    서울특별시 동작구
# 20  11620    서울특별시 관악구
# 21  11650    서울특별시 서초구
# 22  11680    서울특별시 강남구
# 23  11710    서울특별시 송파구
# 24  11740    서울특별시 강동구

# %% [markdown]
# #### 1월 데이터 가공

# %%
adstrd_code_01 = card_01['adstrd_code']
mrhst_induty_cl_code_01 = card_01['mrhst_induty_cl_code']

adstrd_code_new = []
mrhst_induty_cl_code_new = []

for i in adstrd_code_01:
    adstrd_code_new.append(int(i/100000))
    
for i in mrhst_induty_cl_code_01:
    mrhst_induty_cl_code_new.append(int(i/100))

adstrd_code_new

data_card01 = {"receipt_dttm" : card_01['receipt_dttm'], "adstrd_code" : adstrd_code_new, "adstrd_nm" : card_01['adstrd_nm'],
               "mrhst_induty_cl_code": mrhst_induty_cl_code_new, "mrhst_induty_cl_nm" : card_01['mrhst_induty_cl_nm'],
               "selng_cascnt" : card_01['selng_cascnt'], "salamt" : card_01['salamt']}

df_card01 = pd.DataFrame(data_card01)
df_card01.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200104        11740      성내3동                    70
# 1      20200104        11740      성내3동                    70
# 2      20200104        11740      성내3동                    70
# 3      20200104        11740      성내3동                    70
# 4      20200104        11740      성내3동                    61
#
#   mrhst_induty_cl_nm  selng_cascnt     salamt
# 0                 약국           463  5843230.0
# 1               치과의원            33  7835550.0
# 2                한의원            53  4589800.0
# 3                 의원           339  9267240.0
# 4              자동차정비            19  4441000.0

# %%
df_card01['mrhst_induty_cl_code'].value_counts()
code = []
for i in df_card01['mrhst_induty_cl_code'].value_counts().index:
    code.append(i)
print(code , '\n')
print(len(code), "\n")
code.sort()
print(code)
# Out:
# [80, 70, 83, 71, 40, 21, 51, 61, 42, 44, 91, 50, 22, 93, 92, 90, 99, 20, 10, 52, 33, 31, 82, 84, 34, 81, 43, 32, 30, 11, 60, 41, 62, 96, 95]
#
# 35
#
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]

# %%
seoul01 = []
seoul01_sum = []

is_code = df_card01['adstrd_code'] == 11170

for i in code:
    is_name = df_card01['mrhst_induty_cl_code'] == i
    seoul = df_card01[is_code & is_name]
    seoul01.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul01_sum.append(sum_num)
    
seoul01[0]
print(seoul01_sum)
print(code)

mean = []

for i in seoul01_sum:
    mean.append(i/28)

Jongrogu01 = pd.DataFrame({'code' : code, 'total_sum' : seoul01_sum, 'mean' : mean})
Jongrogu01
# Out:
# [6939, 315, 5434, 23659, 109864, 193, 13613, 195, 6375, 588, 7294423, 615129, 6498, 24, 5851, 8144, 2017, 12488, 161, 7740, 26587, 90436, 28604, 909622, 5614, 2831, 326636, 694, 1142, 281406, 3046, 678, 0, 1, 9799]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum           mean
# 0     10       6939     247.821429
# 1     11        315      11.250000
# 2     20       5434     194.071429
# 3     21      23659     844.964286
# 4     22     109864    3923.714286
# 5     30        193       6.892857
# 6     31      13613     486.178571
# 7     32        195       6.964286
# 8     33       6375     227.678571
# 9     34        588      21.000000
# 10    40    7294423  260515.107143
# 11    41     615129   21968.892857
# 12    42       6498     232.071429
# 13    43         24       0.857143
# 14    44       5851     208.964286
# 15    50       8144     290.857143
# 16    51       2017      72.035714
# 17    52      12488     446.000000
# 18    60        161       5.750000
# 19    61       7740     276.428571
# 20    62      26587     949.535714
# 21    70      90436    3229.857143
# 22    71      28604    1021.571429
# 23    80     909622   32486.500000
# 24    81       5614     200.500000
# 25    82       2831     101.107143
# 26    83     326636   11665.571429
# 27    84        694      24.785714
# 28    90       1142      40.785714
# 29    91     281406   10050.214286
# 30    92       3046     108.785714
# 31    93        678      24.214286
# 32    95          0       0.000000
# 33    96          1       0.035714
# 34    99       9799     349.964286

# %% [markdown]
# ### 상대값 = {(n월 평균 - 1월 평균)/(1월 평균)} * 100

# %% [markdown]
# ### 2월 데이터 가공

# %%
adstrd_code_02 = card_02['adstrd_code']
mrhst_induty_cl_code_02 = card_02['mrhst_induty_cl_code']

adstrd_code_new = []
mrhst_induty_cl_code_new = []

for i in adstrd_code_02:
    adstrd_code_new.append(int(i/100000))
    
for i in mrhst_induty_cl_code_02:
    mrhst_induty_cl_code_new.append(int(i/100))

adstrd_code_new

data_card02 = {"receipt_dttm" : card_02['receipt_dttm'], "adstrd_code" : adstrd_code_new, "adstrd_nm" : card_02['adstrd_nm'],
               "mrhst_induty_cl_code": mrhst_induty_cl_code_new, "mrhst_induty_cl_nm" : card_02['mrhst_induty_cl_nm'],
               "selng_cascnt" : card_02['selng_cascnt'], "salamt" : card_02['salamt']}

df_card02 = pd.DataFrame(data_card02)
df_card02.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200201        11680      논현2동                    40
# 1      20200201        11410     북가좌2동                    71
# 2      20200201        11260    면목3.8동                    44
# 3      20200201        11320       창5동                    52
# 4      20200201        11470      신월6동                    90
#
#   mrhst_induty_cl_nm  selng_cascnt     salamt
# 0              대형할인점            67  1007350.0
# 1                사우나             7    49000.0
# 2               기타잡화            11    79400.0
# 3              컴 퓨 터             1    15000.0
# 4             기타건축자재             3    24500.0

# %% [markdown]
# #### 2월 상반기

# %%
is_date = df_card02['receipt_dttm'] < 20200215
df_card02_1 = df_card02[is_date]
df_card02_1.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200201        11680      논현2동                    40
# 1      20200201        11410     북가좌2동                    71
# 2      20200201        11260    면목3.8동                    44
# 3      20200201        11320       창5동                    52
# 4      20200201        11470      신월6동                    90
#
#   mrhst_induty_cl_nm  selng_cascnt     salamt
# 0              대형할인점            67  1007350.0
# 1                사우나             7    49000.0
# 2               기타잡화            11    79400.0
# 3              컴 퓨 터             1    15000.0
# 4             기타건축자재             3    24500.0

# %%
seoul02_1 = []
seoul02_sum_1 = []

is_code = df_card02_1['adstrd_code'] == 11170

for i in code:
    is_name = df_card02_1['mrhst_induty_cl_code'] == i
    seoul = df_card02_1[is_code & is_name]
    seoul02_1.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul02_sum_1.append(sum_num)
    
print(seoul02_sum_1)
print(code)

mean = []

for i in seoul02_sum_1:
    mean.append(i/14)

Jongrogu02_1 = pd.DataFrame({'code' : code, 'total_sum' : seoul02_sum_1, 'mean' : mean})
Jongrogu02_1
# Out:
# [2547, 178, 1080, 7865, 28665, 158, 2861, 115, 4039, 326, 1655364, 405506, 1989, 14, 2155, 3741, 731, 3280, 102, 3108, 16491, 24813, 6693, 184597, 1018, 714, 60237, 270, 841, 80367, 1130, 450, 0, 1, 3694]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum           mean
# 0     10       2547     181.928571
# 1     11        178      12.714286
# 2     20       1080      77.142857
# 3     21       7865     561.785714
# 4     22      28665    2047.500000
# 5     30        158      11.285714
# 6     31       2861     204.357143
# 7     32        115       8.214286
# 8     33       4039     288.500000
# 9     34        326      23.285714
# 10    40    1655364  118240.285714
# 11    41     405506   28964.714286
# 12    42       1989     142.071429
# 13    43         14       1.000000
# 14    44       2155     153.928571
# 15    50       3741     267.214286
# 16    51        731      52.214286
# 17    52       3280     234.285714
# 18    60        102       7.285714
# 19    61       3108     222.000000
# 20    62      16491    1177.928571
# 21    70      24813    1772.357143
# 22    71       6693     478.071429
# 23    80     184597   13185.500000
# 24    81       1018      72.714286
# 25    82        714      51.000000
# 26    83      60237    4302.642857
# 27    84        270      19.285714
# 28    90        841      60.071429
# 29    91      80367    5740.500000
# 30    92       1130      80.714286
# 31    93        450      32.142857
# 32    95          0       0.000000
# 33    96          1       0.071429
# 34    99       3694     263.857143

# %% [markdown]
# ### 1월&2월(상반기) 평균 비교

# %%
per_02_1 = []

for i in range(0, len(Jongrogu01['mean'])) :
    a = Jongrogu01['mean'][i]
    b = Jongrogu02_1['mean'][i]
    if(a != 0):
        per_02_1.append( ( ( b - a ) / a ) * 100 )
    else:
        per_02_1.append(-1)
per_02_1
# Out:
# [-26.588845654993527,
#  13.015873015873009,
#  -60.25027603974973,
#  -33.51367344350986,
#  -47.81730139081046,
#  63.730569948186535,
#  -57.9666495261882,
#  17.948717948717935,
#  26.713725490196083,
#  10.884353741496595,
#  -54.61288713308784,
#  31.844214790718688,
#  -38.78116343490304,
#  16.666666666666675,
#  -26.337378225944292,
#  -8.128683693516688,
#  -27.516113039167085,
#  -47.46957078795644,
#  26.70807453416149,
#  -19.689922480620158,
#  24.053108662128093,
#  -45.125834844530935,
#  -53.20234932177318,
#  -59.412371292690814,
#  -63.73352333452085,
#  -49.55845990815966,
#  -63.116741571657755,
#  -22.19020172910663,
#  47.285464098073554,
#  -42.881814886676196,
#  -25.804333552199616,
#  32.74336283185841,
#  -1,
#  100.0,
#  -24.604551484845402]

# %%
data_02_1 = pd.DataFrame({"code": code, "mean": per_02_1})
data_02_1.plot(x = "code", y = "mean", kind = 'bar')

# '종로구' 의 1월 평균과 2월 평균(상반기)을 각 항목별로 비교한 그래프

# %% [markdown]
# #### 2월 하반기

# %%
is_date = df_card02['receipt_dttm'] > 20200214
df_card02_2 = df_card02[is_date]
df_card02_2.head()
# Out:
#         receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 160531      20200215        11710      거여1동                    70
# 160532      20200215        11680      대치4동                    70
# 160533      20200215        11650      서초1동                    80
# 160534      20200215        11440       대흥동                    71
# 160535      20200215        11260      망우본동                    70
#
#        mrhst_induty_cl_nm  selng_cascnt      salamt
# 160531               동물병원            13    730100.0
# 160532                 약국           442   7531530.0
# 160533               서양음식          1840  19929464.0
# 160534              미 용 원            59   2890700.0
# 160535                 약국           394   6041060.0

# %%
seoul02_2 = []
seoul02_sum_2 = []

is_code = df_card02_2['adstrd_code'] == 11170

for i in code:
    is_name = df_card02_2['mrhst_induty_cl_code'] == i
    seoul = df_card02_2[is_code & is_name]
    seoul02_2.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul02_sum_2.append(sum_num)
    
seoul02_2[0]
print(seoul02_sum_2)
print(code)

mean = []

for i in seoul02_sum_2:
    mean.append(i/15)

Jongrogu02_2 = pd.DataFrame({'code' : code, 'total_sum' : seoul02_sum_2, 'mean' : mean})
Jongrogu02_2
# Out:
# [5832, 375, 2704, 18370, 69754, 372, 6712, 312, 9565, 797, 4227155, 1091585, 4277, 46, 5333, 7539, 2799, 7664, 334, 7775, 40870, 57861, 14798, 446115, 3062, 1837, 142919, 570, 2080, 317640, 2687, 1045, 0, 1, 11677]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum           mean
# 0     10       5832     388.800000
# 1     11        375      25.000000
# 2     20       2704     180.266667
# 3     21      18370    1224.666667
# 4     22      69754    4650.266667
# 5     30        372      24.800000
# 6     31       6712     447.466667
# 7     32        312      20.800000
# 8     33       9565     637.666667
# 9     34        797      53.133333
# 10    40    4227155  281810.333333
# 11    41    1091585   72772.333333
# 12    42       4277     285.133333
# 13    43         46       3.066667
# 14    44       5333     355.533333
# 15    50       7539     502.600000
# 16    51       2799     186.600000
# 17    52       7664     510.933333
# 18    60        334      22.266667
# 19    61       7775     518.333333
# 20    62      40870    2724.666667
# 21    70      57861    3857.400000
# 22    71      14798     986.533333
# 23    80     446115   29741.000000
# 24    81       3062     204.133333
# 25    82       1837     122.466667
# 26    83     142919    9527.933333
# 27    84        570      38.000000
# 28    90       2080     138.666667
# 29    91     317640   21176.000000
# 30    92       2687     179.133333
# 31    93       1045      69.666667
# 32    95          0       0.000000
# 33    96          1       0.066667
# 34    99      11677     778.466667

# %% [markdown]
# ### 1월 & 2월(하반기) 평균 비교

# %%
per_02_2 = []

for i in range(0, len(Jongrogu01['mean'])) :
    a = Jongrogu01['mean'][i]
    b = Jongrogu02_2['mean'][i]
    if(a != 0):
        per_02_2.append( ( ( b - a ) / a ) * 100 )
    else:
        per_02_2.append(-1)
per_02_2
# Out:
# [56.88715953307393,
#  122.22222222222223,
#  -7.113237639553429,
#  44.93709229750485,
#  18.516954295007153,
#  259.79274611398966,
#  -7.962486838561188,
#  198.66666666666666,
#  180.07320261437906,
#  153.015873015873,
#  8.17427688705924,
#  231.25171034585154,
#  22.864471119318754,
#  257.77777777777777,
#  70.14071668660628,
#  72.79960707269157,
#  159.03817550818044,
#  14.559043348281017,
#  287.2463768115942,
#  87.51076658053402,
#  186.94725492408568,
#  19.42943075766289,
#  -3.429823334731741,
#  -8.451202807319962,
#  1.8121363258520329,
#  21.125632874131632,
#  -18.324332488356063,
#  53.31412103746398,
#  239.9883245767659,
#  110.70197508226546,
#  64.66622893412124,
#  187.70894788593904,
#  -1,
#  86.66666666666667,
#  122.4417457563697]

# %%
data_02_2 = pd.DataFrame({"code": code, "mean": per_02_2})
data_02_2.plot(x = "code", y = "mean", kind = 'bar')

# %% [markdown]
# ### 3월 데이터 가공

# %%
adstrd_code_03 = card_03['adstrd_code']
mrhst_induty_cl_code_03 = card_03['mrhst_induty_cl_code']

adstrd_code_new = []
mrhst_induty_cl_code_new = []

for i in adstrd_code_03:
    adstrd_code_new.append(int(i/100000))
    
for i in mrhst_induty_cl_code_03:
    mrhst_induty_cl_code_new.append(int(i/100))

adstrd_code_new

data_card03 = {"receipt_dttm" : card_03['receipt_dttm'], "adstrd_code" : adstrd_code_new, "adstrd_nm" : card_03['adstrd_nm'],
               "mrhst_induty_cl_code": mrhst_induty_cl_code_new, "mrhst_induty_cl_nm" : card_03['mrhst_induty_cl_nm'],
               "selng_cascnt" : card_03['selng_cascnt'], "salamt" : card_03['salamt']}

df_card03 = pd.DataFrame(data_card03)
df_card03.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200301        11545      시흥4동                    90
# 1      20200301        11140       광희동                    80
# 2      20200301        11710      잠실본동                    71
# 3      20200301        11620       서림동                    83
# 4      20200301        11740      둔촌2동                    71
#
#   mrhst_induty_cl_nm  selng_cascnt      salamt
# 0              조명 기구             1     15000.0
# 1               일반한식           952  25644550.0
# 2              미 용 원           121   6493950.0
# 3              정 육 점            50   1273200.0
# 4              미 용 원            47   1636300.0

# %% [markdown]
# ### 3월 상반기

# %%
is_date = df_card03['receipt_dttm'] < 20200316
df_card03_1 = df_card03[is_date]
df_card03_1.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200301        11545      시흥4동                    90
# 1      20200301        11140       광희동                    80
# 2      20200301        11710      잠실본동                    71
# 3      20200301        11620       서림동                    83
# 4      20200301        11740      둔촌2동                    71
#
#   mrhst_induty_cl_nm  selng_cascnt      salamt
# 0              조명 기구             1     15000.0
# 1               일반한식           952  25644550.0
# 2              미 용 원           121   6493950.0
# 3              정 육 점            50   1273200.0
# 4              미 용 원            47   1636300.0

# %%
seoul03_1 = []
seoul03_sum_1 = []

is_code = df_card03_1['adstrd_code'] == 11170

for i in code:
    is_name = df_card03_1['mrhst_induty_cl_code'] == i
    seoul = df_card03_1[is_code & is_name]
    seoul03_1.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul03_sum_1.append(sum_num)
    
print(seoul03_sum_1)
print(code)

mean = []

for i in seoul03_sum_1:
    mean.append(i/15)

Jongrogu03_1 = pd.DataFrame({'code' : code, 'total_sum' : seoul03_sum_1, 'mean' : mean})
Jongrogu03_1
# Out:
# [3620, 212, 2444, 15961, 26998, 423, 6772, 324, 8667, 640, 4176235, 1093129, 3657, 29, 4595, 6847, 533, 7631, 376, 8253, 24274, 57851, 11960, 373778, 2171, 1059, 111236, 392, 2292, 848778, 2740, 736, 0, 6, 10906]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum           mean
# 0     10       3620     241.333333
# 1     11        212      14.133333
# 2     20       2444     162.933333
# 3     21      15961    1064.066667
# 4     22      26998    1799.866667
# 5     30        423      28.200000
# 6     31       6772     451.466667
# 7     32        324      21.600000
# 8     33       8667     577.800000
# 9     34        640      42.666667
# 10    40    4176235  278415.666667
# 11    41    1093129   72875.266667
# 12    42       3657     243.800000
# 13    43         29       1.933333
# 14    44       4595     306.333333
# 15    50       6847     456.466667
# 16    51        533      35.533333
# 17    52       7631     508.733333
# 18    60        376      25.066667
# 19    61       8253     550.200000
# 20    62      24274    1618.266667
# 21    70      57851    3856.733333
# 22    71      11960     797.333333
# 23    80     373778   24918.533333
# 24    81       2171     144.733333
# 25    82       1059      70.600000
# 26    83     111236    7415.733333
# 27    84        392      26.133333
# 28    90       2292     152.800000
# 29    91     848778   56585.200000
# 30    92       2740     182.666667
# 31    93        736      49.066667
# 32    95          0       0.000000
# 33    96          6       0.400000
# 34    99      10906     727.066667

# %% [markdown]
# ### 1월 & 3월 (상반기) 평균 비교

# %%
per_03_1 = []

for i in range(0, len(Jongrogu01['mean'])) :
    a = Jongrogu01['mean'][i]
    b = Jongrogu03_1['mean'][i]
    if(a != 0):
        per_03_1.append( ( ( b - a ) / a ) * 100 )
    else:
        per_03_1.append(-1)
per_03_1
# Out:
# [-2.618052553201711,
#  25.629629629629626,
#  -16.044657097288678,
#  25.93037181058653,
#  -54.128498264521,
#  309.11917098445593,
#  -7.139743872278957,
#  210.15384615384613,
#  153.77882352941174,
#  103.17460317460316,
#  6.871217458415389,
#  231.7202516328553,
#  5.05386272699292,
#  125.55555555555557,
#  46.59602347177119,
#  56.938441388343165,
#  -50.67261609651298,
#  14.065769805680123,
#  335.94202898550725,
#  99.03875968992249,
#  70.42715111395293,
#  19.408790009878075,
#  -21.950309979956177,
#  -23.295727969053814,
#  -27.813798836242732,
#  -30.17308371600142,
#  -36.43060368932594,
#  5.43707973102786,
#  274.6409807355517,
#  463.0248111269837,
#  67.91420442109869,
#  102.63520157325468,
#  -1,
#  1020.0000000000001,
#  107.75453277545328]

# %%
data_03_1 = pd.DataFrame({"code": code, "mean": per_03_1})
data_03_1.plot(x = "code", y = "mean", kind = 'bar')

# %% [markdown]
# ### 3월 하반기

# %%
is_date = df_card03['receipt_dttm'] > 20200315
df_card03_2 = df_card03[is_date]
df_card03_2.head()
# Out:
#         receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 376104      20200316        11290       삼선동                    10
# 376105      20200316        11680      역삼1동                    80
# 376106      20200316        11440       서교동                    80
# 376107      20200316        11740      명일2동                    40
# 376108      20200316        11380      갈현1동                    71
#
#        mrhst_induty_cl_nm  selng_cascnt       salamt
# 376104              기타숙박업            12     528000.0
# 376105               서양음식          5424   70725305.0
# 376106               일반한식          4441  131872050.0
# 376107              편 의 점           404    2209050.0
# 376108              미 용 원            37    1616800.0

# %%
seoul03_2 = []
seoul03_sum_2 = []

is_code = df_card03_2['adstrd_code'] == 11170

for i in code:
    is_name = df_card03_2['mrhst_induty_cl_code'] == i
    seoul = df_card03_2[is_code & is_name]
    seoul03_2.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul03_sum_2.append(sum_num)
    
seoul03_2[0]
print(seoul03_sum_2)
print(code)

mean = []

for i in seoul03_sum_2:
    mean.append(i/16)

Jongrogu03_2 = pd.DataFrame({'code' : code, 'total_sum' : seoul03_sum_2, 'mean' : mean})
Jongrogu03_2
# Out:
# [3341, 304, 3121, 15022, 20133, 432, 7791, 361, 8832, 718, 4927871, 1205140, 4432, 55, 5230, 7743, 2516, 7715, 424, 10182, 41090, 69643, 13735, 408586, 1008, 763, 119424, 414, 2361, 303750, 3229, 886, 0, 2, 6555]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum         mean
# 0     10       3341     208.8125
# 1     11        304      19.0000
# 2     20       3121     195.0625
# 3     21      15022     938.8750
# 4     22      20133    1258.3125
# 5     30        432      27.0000
# 6     31       7791     486.9375
# 7     32        361      22.5625
# 8     33       8832     552.0000
# 9     34        718      44.8750
# 10    40    4927871  307991.9375
# 11    41    1205140   75321.2500
# 12    42       4432     277.0000
# 13    43         55       3.4375
# 14    44       5230     326.8750
# 15    50       7743     483.9375
# 16    51       2516     157.2500
# 17    52       7715     482.1875
# 18    60        424      26.5000
# 19    61      10182     636.3750
# 20    62      41090    2568.1250
# 21    70      69643    4352.6875
# 22    71      13735     858.4375
# 23    80     408586   25536.6250
# 24    81       1008      63.0000
# 25    82        763      47.6875
# 26    83     119424    7464.0000
# 27    84        414      25.8750
# 28    90       2361     147.5625
# 29    91     303750   18984.3750
# 30    92       3229     201.8125
# 31    93        886      55.3750
# 32    95          0       0.0000
# 33    96          2       0.1250
# 34    99       6555     409.6875

# %% [markdown]
# ### 1월 & 3월(하반기) 평균 비교

# %%
per_03_2 = []

for i in range(0, len(Jongrogu01['mean'])) :
    a = Jongrogu01['mean'][i]
    b = Jongrogu03_2['mean'][i]
    if(a != 0):
        per_03_2.append( ( ( b - a ) / a ) * 100 )
    else:
        per_03_2.append(-1)
per_03_2
# Out:
# [-15.740740740740744,
#  68.88888888888889,
#  0.5106735369893202,
#  11.114163743184418,
#  -67.93057780528655,
#  291.70984455958546,
#  0.15610078601336624,
#  223.97435897435892,
#  142.4470588235294,
#  113.69047619047619,
#  18.22421389601344,
#  242.8541005220043,
#  19.359803016312704,
#  301.0416666666667,
#  56.426251922748236,
#  66.38322691552064,
#  118.29449677739214,
#  8.113789237668161,
#  360.8695652173913,
#  130.21317829457365,
#  170.46112761876105,
#  34.76408731036314,
#  -15.968920430708991,
#  -21.393117140966247,
#  -68.5785536159601,
#  -52.83468738961498,
#  -36.016850561481284,
#  4.394812680115278,
#  261.79947460595446,
#  88.89522611458177,
#  85.51378857518056,
#  128.68731563421827,
#  -1,
#  250.0,
#  17.065516889478516]

# %%
data_03_2 = pd.DataFrame({"code": code, "mean": per_03_2})
data_03_2.plot(x = "code", y = "mean", kind = 'bar')

# %% [markdown]
# ### 4월 데이터 가공

# %%
adstrd_code_04 = card_04['adstrd_code']
mrhst_induty_cl_code_04 = card_04['mrhst_induty_cl_code']

adstrd_code_new = []
mrhst_induty_cl_code_new = []

for i in adstrd_code_04:
    adstrd_code_new.append(int(i/100000))
    
for i in mrhst_induty_cl_code_04:
    mrhst_induty_cl_code_new.append(int(i/100))

adstrd_code_new

data_card04 = {"receipt_dttm" : card_04['receipt_dttm'], "adstrd_code" : adstrd_code_new, "adstrd_nm" : card_04['adstrd_nm'],
               "mrhst_induty_cl_code": mrhst_induty_cl_code_new, "mrhst_induty_cl_nm" : card_04['mrhst_induty_cl_nm'],
               "selng_cascnt" : card_04['selng_cascnt'], "salamt" : card_04['salamt']}

df_card04 = pd.DataFrame(data_card04)
df_card04.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200401        11530      구로5동                    92
# 1      20200401        11680       신사동                    42
# 2      20200401        11710       오금동                    44
# 3      20200401        11620       난향동                    21
# 4      20200401        11710      가락2동                    70
#
#   mrhst_induty_cl_nm  selng_cascnt     salamt
# 0             가정용품수리            43  3458100.0
# 1              스포츠의류             1   516800.0
# 2               기타잡화             1    85000.0
# 3              기타레져업            19    95300.0
# 4               제약회사             7  6700000.0

# %% [markdown]
# #### 4월 상반기

# %%
is_date = df_card04['receipt_dttm'] < 20200416
df_card04_1 = df_card04[is_date]
df_card04_1.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200401        11530      구로5동                    92
# 1      20200401        11680       신사동                    42
# 2      20200401        11710       오금동                    44
# 3      20200401        11620       난향동                    21
# 4      20200401        11710      가락2동                    70
#
#   mrhst_induty_cl_nm  selng_cascnt     salamt
# 0             가정용품수리            43  3458100.0
# 1              스포츠의류             1   516800.0
# 2               기타잡화             1    85000.0
# 3              기타레져업            19    95300.0
# 4               제약회사             7  6700000.0

# %%
seoul04_1 = []
seoul04_sum_1 = []

is_code = df_card04_1['adstrd_code'] == 11170

for i in code:
    is_name = df_card04_1['mrhst_induty_cl_code'] == i
    seoul = df_card04_1[is_code & is_name]
    seoul04_1.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul04_sum_1.append(sum_num)
    
print(seoul04_sum_1)
print(code)

mean = []

for i in seoul04_sum_1:
    mean.append(i/15)

Jongrogu04_1 = pd.DataFrame({'code' : code, 'total_sum' : seoul04_sum_1, 'mean' : mean})
Jongrogu04_1
# Out:
# [3627, 322, 3218, 13860, 12472, 468, 7123, 409, 8707, 622, 4071906, 1151541, 4444, 49, 5195, 7207, 684, 8032, 457, 10115, 26940, 68244, 12488, 395755, 352, 414, 120387, 431, 2262, 873796, 3327, 773, 0, 4, 9838]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum           mean
# 0     10       3627     241.800000
# 1     11        322      21.466667
# 2     20       3218     214.533333
# 3     21      13860     924.000000
# 4     22      12472     831.466667
# 5     30        468      31.200000
# 6     31       7123     474.866667
# 7     32        409      27.266667
# 8     33       8707     580.466667
# 9     34        622      41.466667
# 10    40    4071906  271460.400000
# 11    41    1151541   76769.400000
# 12    42       4444     296.266667
# 13    43         49       3.266667
# 14    44       5195     346.333333
# 15    50       7207     480.466667
# 16    51        684      45.600000
# 17    52       8032     535.466667
# 18    60        457      30.466667
# 19    61      10115     674.333333
# 20    62      26940    1796.000000
# 21    70      68244    4549.600000
# 22    71      12488     832.533333
# 23    80     395755   26383.666667
# 24    81        352      23.466667
# 25    82        414      27.600000
# 26    83     120387    8025.800000
# 27    84        431      28.733333
# 28    90       2262     150.800000
# 29    91     873796   58253.066667
# 30    92       3327     221.800000
# 31    93        773      51.533333
# 32    95          0       0.000000
# 33    96          4       0.266667
# 34    99       9838     655.866667

# %% [markdown]
# ### 1월&4월(상반기) 평균 비교

# %%
per_04_1 = []

for i in range(0, len(Jongrogu01['mean'])) :
    a = Jongrogu01['mean'][i]
    b = Jongrogu04_1['mean'][i]
    if(a != 0):
        per_04_1.append( ( ( b - a ) / a ) * 100 )
    else:
        per_04_1.append(-1)
per_04_1
# Out:
# [-2.429744920017294,
#  90.81481481481481,
#  10.543491596123166,
#  9.35373430829706,
#  -78.80919439792228,
#  352.6424870466321,
#  -2.3266975195279036,
#  291.5213675213675,
#  154.95006535947712,
#  97.46031746031747,
#  4.201404278309622,
#  249.44592109947666,
#  27.661844670154906,
#  281.11111111111114,
#  65.73805047570215,
#  65.18991486574984,
#  -36.69806643529995,
#  20.05979073243648,
#  429.8550724637681,
#  143.9448751076658,
#  89.14507089931169,
#  40.86071918262641,
#  -18.504638045960938,
#  -18.785752030330542,
#  -88.29592684954281,
#  -72.70222536206288,
#  -31.20096988696898,
#  15.926993275696455,
#  269.73730297723296,
#  479.62014550743993,
#  103.887065003283,
#  112.82202556538839,
#  -1,
#  646.6666666666667,
#  87.40959961900873]

# %%
data_04_1 = pd.DataFrame({"code": code, "mean": per_04_1})
data_04_1.plot(x = "code", y = "mean", kind = 'bar')

# '종로구' 의 1월 평균과 2월 평균(상반기)을 각 항목별로 비교한 그래프

# %% [markdown]
# ## 4월(하반기) 데이터 가공

# %%
is_date = df_card04['receipt_dttm'] > 20200415
df_card04_2 = df_card04[is_date]
df_card04_2.head()
# Out:
#         receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 385832      20200416        11710      마천2동                    80
# 385833      20200416        11590      사당1동                    44
# 385834      20200416        11710      잠실2동                    80
# 385835      20200416        11170       남영동                    70
# 385836      20200416        11680      압구정동                    70
#
#        mrhst_induty_cl_nm  selng_cascnt      salamt
# 385832               일식회집            10    516000.0
# 385833              악세 사리            30    451450.0
# 385834               일반한식           153   1770930.0
# 385835                한의원             8    252000.0
# 385836                 의원           169  67386370.0

# %%
seoul04_2 = []
seoul04_sum_2 = []

is_code = df_card04_2['adstrd_code'] == 11170

for i in code:
    is_name = df_card04_2['mrhst_induty_cl_code'] == i
    seoul = df_card04_2[is_code & is_name]
    seoul04_2.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul04_sum_2.append(sum_num)
    
seoul04_2[0]
print(seoul04_sum_2)
print(code)

mean = []

for i in seoul04_sum_2:
    mean.append(i/15)

Jongrogu04_2 = pd.DataFrame({'code' : code, 'total_sum' : seoul04_sum_2, 'mean' : mean})
Jongrogu04_2
# Out:
# [3718, 312, 3591, 15669, 14631, 526, 6813, 409, 8694, 705, 4137140, 1034081, 4892, 43, 5488, 7414, 2667, 7364, 491, 9731, 42584, 65340, 14016, 424500, 1458, 606, 130566, 510, 2250, 298550, 3099, 899, 0, 4, 6312]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum           mean
# 0     10       3718     247.866667
# 1     11        312      20.800000
# 2     20       3591     239.400000
# 3     21      15669    1044.600000
# 4     22      14631     975.400000
# 5     30        526      35.066667
# 6     31       6813     454.200000
# 7     32        409      27.266667
# 8     33       8694     579.600000
# 9     34        705      47.000000
# 10    40    4137140  275809.333333
# 11    41    1034081   68938.733333
# 12    42       4892     326.133333
# 13    43         43       2.866667
# 14    44       5488     365.866667
# 15    50       7414     494.266667
# 16    51       2667     177.800000
# 17    52       7364     490.933333
# 18    60        491      32.733333
# 19    61       9731     648.733333
# 20    62      42584    2838.933333
# 21    70      65340    4356.000000
# 22    71      14016     934.400000
# 23    80     424500   28300.000000
# 24    81       1458      97.200000
# 25    82        606      40.400000
# 26    83     130566    8704.400000
# 27    84        510      34.000000
# 28    90       2250     150.000000
# 29    91     298550   19903.333333
# 30    92       3099     206.600000
# 31    93        899      59.933333
# 32    95          0       0.000000
# 33    96          4       0.266667
# 34    99       6312     420.800000

# %%
per_04_2 = []

for i in range(0, len(Jongrogu01['mean'])) :
    a = Jongrogu01['mean'][i]
    b = Jongrogu04_2['mean'][i]
    if(a != 0):
        per_04_2.append( ( ( b - a ) / a ) * 100 )
    else:
        per_04_2.append(-1)
per_04_2
# Out:
# [0.018254311380120156,
#  84.88888888888889,
#  23.356643356643353,
#  23.626526903081277,
#  -75.14090147819121,
#  408.7392055267704,
#  -6.577536178652764,
#  291.5213675213675,
#  154.56941176470588,
#  123.80952380952381,
#  5.870763641391967,
#  213.80158199878943,
#  40.53144557299681,
#  234.44444444444446,
#  75.08574032928844,
#  69.93451211525868,
#  146.82201289043132,
#  10.07473841554559,
#  469.2753623188406,
#  134.6838931955211,
#  198.98120635398254,
#  34.86664602591889,
#  -8.533072297580759,
#  -12.886891477998553,
#  -51.5211970074813,
#  -60.04238784881668,
#  -25.383852361650284,
#  37.17579250720462,
#  267.7758318739055,
#  98.03889516688815,
#  89.91464215364411,
#  147.51229105211402,
#  -1,
#  646.6666666666667,
#  20.24084090213287]

# %%
data_04_2 = pd.DataFrame({"code": code, "mean": per_04_2})
data_04_2.plot(x = "code", y = "mean", kind = 'bar')

# %% [markdown]
# ### 5월 데이터 가공

# %%
adstrd_code_05 = card_05['adstrd_code']
mrhst_induty_cl_code_05 = card_05['mrhst_induty_cl_code']

adstrd_code_new = []
mrhst_induty_cl_code_new = []

for i in adstrd_code_05:
    adstrd_code_new.append(int(i/100000))
    
for i in mrhst_induty_cl_code_05:
    mrhst_induty_cl_code_new.append(int(i/100))

adstrd_code_new

data_card05 = {"receipt_dttm" : card_05['receipt_dttm'], "adstrd_code" : adstrd_code_new, "adstrd_nm" : card_05['adstrd_nm'],
               "mrhst_induty_cl_code": mrhst_induty_cl_code_new, "mrhst_induty_cl_nm" : card_05['mrhst_induty_cl_nm'],
               "selng_cascnt" : card_05['selng_cascnt'], "salamt" : card_05['salamt']}

df_card05 = pd.DataFrame(data_card05)
df_card05.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200501        11500      화곡2동                    83
# 1      20200501        11215      자양1동                    80
# 2      20200501        11560       문래동                    61
# 3      20200501        11620       신사동                    80
# 4      20200501        11200    성수1가2동                    61
#
#   mrhst_induty_cl_nm  selng_cascnt     salamt
# 0              정 육 점          17.0   481200.0
# 1                 스넥         188.0  2777400.0
# 2              주 차 장          63.0   375000.0
# 3               서양음식         406.0  3421500.0
# 4              주 차 장          37.0   259500.0

# %% [markdown]
# ### 5월 상반기

# %%
is_date = df_card05['receipt_dttm'] < 20200516
df_card05_1 = df_card05[is_date]
df_card05_1.head()
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200501        11500      화곡2동                    83
# 1      20200501        11215      자양1동                    80
# 2      20200501        11560       문래동                    61
# 3      20200501        11620       신사동                    80
# 4      20200501        11200    성수1가2동                    61
#
#   mrhst_induty_cl_nm  selng_cascnt     salamt
# 0              정 육 점          17.0   481200.0
# 1                 스넥         188.0  2777400.0
# 2              주 차 장          63.0   375000.0
# 3               서양음식         406.0  3421500.0
# 4              주 차 장          37.0   259500.0

# %%
seoul05_1 = []
seoul05_sum_1 = []

is_code = df_card05_1['adstrd_code'] == 11170

for i in code:
    is_name = df_card05_1['mrhst_induty_cl_code'] == i
    seoul = df_card05_1[is_code & is_name]
    seoul05_1.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul05_sum_1.append(sum_num)
    
print(seoul05_sum_1)
print(code)

mean = []

for i in seoul05_sum_1:
    mean.append(i/15)

Jongrogu05_1 = pd.DataFrame({'code' : code, 'total_sum' : seoul05_sum_1, 'mean' : mean})
Jongrogu05_1
# Out:
# [9743, 2628, 14880, 37384, 33389, 6981, 12905, 3331, 7492, 7059, 1479656, 297768, 22344, 1189, 23716, 28168, 13499, 16043, 5797, 30630, 1481, 91593, 61198, 303867, 4439, 6859, 107454, 3603, 42432, 63481, 23117, 8806, 0, 5, 84274]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum          mean
# 0     10       9743    649.533333
# 1     11       2628    175.200000
# 2     20      14880    992.000000
# 3     21      37384   2492.266667
# 4     22      33389   2225.933333
# 5     30       6981    465.400000
# 6     31      12905    860.333333
# 7     32       3331    222.066667
# 8     33       7492    499.466667
# 9     34       7059    470.600000
# 10    40    1479656  98643.733333
# 11    41     297768  19851.200000
# 12    42      22344   1489.600000
# 13    43       1189     79.266667
# 14    44      23716   1581.066667
# 15    50      28168   1877.866667
# 16    51      13499    899.933333
# 17    52      16043   1069.533333
# 18    60       5797    386.466667
# 19    61      30630   2042.000000
# 20    62       1481     98.733333
# 21    70      91593   6106.200000
# 22    71      61198   4079.866667
# 23    80     303867  20257.800000
# 24    81       4439    295.933333
# 25    82       6859    457.266667
# 26    83     107454   7163.600000
# 27    84       3603    240.200000
# 28    90      42432   2828.800000
# 29    91      63481   4232.066667
# 30    92      23117   1541.133333
# 31    93       8806    587.066667
# 32    95          0      0.000000
# 33    96          5      0.333333
# 34    99      84274   5618.266667

# %% [markdown]
# ### 1월&5월(상반기) 평균 비교

# %%
per_05_1 = []

for i in range(0, len(Jongrogu01['mean'])) :
    a = Jongrogu01['mean'][i]
    b = Jongrogu05_1['mean'][i]
    if(a != 0):
        per_05_1.append( ( ( b - a ) / a ) * 100 )
    else:
        per_05_1.append(-1)
per_05_1
# Out:
# [162.09732430225296,
#  1457.3333333333333,
#  411.15200588884795,
#  194.95526719923356,
#  -43.26973955678536,
#  6651.917098445595,
#  76.95829966453636,
#  3088.6495726495723,
#  119.37359477124186,
#  2140.952380952381,
#  -62.135119757473156,
#  -9.639506510016602,
#  541.8713450292397,
#  9147.777777777777,
#  656.6205207087106,
#  545.6319580877538,
#  1149.2877210378447,
#  139.80568011958147,
#  6621.159420289855,
#  638.7080103359172,
#  -89.60193578315216,
#  89.05480118536866,
#  299.3716496527293,
#  -37.64240530681976,
#  47.59767248545303,
#  352.25950782997757,
#  -38.59194944831555,
#  869.106628242075,
#  6835.761821366026,
#  -57.89078176489959,
#  1316.6688553293939,
#  2324.464110127827,
#  -1,
#  833.3333333333334,
#  1505.3828621968228]

# %%
data_05_1 = pd.DataFrame({"code": code, "mean": per_05_1})
data_05_1.plot(x = "code", y = "mean", kind = 'bar')

# '종로구' 의 1월 평균과 2월 평균(상반기)을 각 항목별로 비교한 그래프

# %% [markdown]
# ## 5월(하반기) 데이터 가공

# %%
is_date = df_card05['receipt_dttm'] > 20200515
df_card05_2 = df_card05[is_date]
df_card05_2.head()
# Out:
#         receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 389400      20200516        11680      삼성1동                    21
# 389401      20200516        11650      방배4동                    83
# 389402      20200516        11650      서초4동                    21
# 389403      20200516        11500      가양1동                    40
# 389404      20200516        11140       소공동                    80
#
#        mrhst_induty_cl_nm  selng_cascnt      salamt
# 389400              스크린골프         462.0    422000.0
# 389401                미곡상        4949.0    190000.0
# 389402                당구장         276.0    188800.0
# 389403              편 의 점          33.0  30976350.0
# 389404                 스넥         835.0   5590800.0

# %%
seoul05_2 = []
seoul05_sum_2 = []

is_code = df_card05_2['adstrd_code'] == 11170

for i in code:
    is_name = df_card05_2['mrhst_induty_cl_code'] == i
    seoul = df_card05_2[is_code & is_name]
    seoul05_2.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul05_sum_2.append(sum_num)
    
seoul05_2[0]
print(seoul05_sum_2)
print(code)

mean = []

for i in seoul05_sum_2:
    mean.append(i/16)

Jongrogu05_2 = pd.DataFrame({'code' : code, 'total_sum' : seoul05_sum_2, 'mean' : mean})
Jongrogu05_2
# Out:
# [27337, 4147, 18925, 75764, 45699, 7539, 26174, 8202, 10411, 8491, 119240, 3135, 38041, 9304, 50119, 46860, 38171, 30113, 7267, 48198, 282, 124873, 113254, 534112, 173, 7111, 125506, 5810, 102971, 48173, 98418, 16830, 0, 158, 13034]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum        mean
# 0     10      27337   1708.5625
# 1     11       4147    259.1875
# 2     20      18925   1182.8125
# 3     21      75764   4735.2500
# 4     22      45699   2856.1875
# 5     30       7539    471.1875
# 6     31      26174   1635.8750
# 7     32       8202    512.6250
# 8     33      10411    650.6875
# 9     34       8491    530.6875
# 10    40     119240   7452.5000
# 11    41       3135    195.9375
# 12    42      38041   2377.5625
# 13    43       9304    581.5000
# 14    44      50119   3132.4375
# 15    50      46860   2928.7500
# 16    51      38171   2385.6875
# 17    52      30113   1882.0625
# 18    60       7267    454.1875
# 19    61      48198   3012.3750
# 20    62        282     17.6250
# 21    70     124873   7804.5625
# 22    71     113254   7078.3750
# 23    80     534112  33382.0000
# 24    81        173     10.8125
# 25    82       7111    444.4375
# 26    83     125506   7844.1250
# 27    84       5810    363.1250
# 28    90     102971   6435.6875
# 29    91      48173   3010.8125
# 30    92      98418   6151.1250
# 31    93      16830   1051.8750
# 32    95          0      0.0000
# 33    96        158      9.8750
# 34    99      13034    814.6250

# %%
per_05_2 = []

for i in range(0, len(Jongrogu01['mean'])) :
    a = Jongrogu01['mean'][i]
    b = Jongrogu05_2['mean'][i]
    if(a != 0):
        per_05_2.append( ( ( b - a ) / a ) * 100 )
    else:
        per_05_2.append(-1)
per_05_2
# Out:
# [589.4329154056779,
#  2203.8888888888887,
#  509.47276407802724,
#  460.40830128069655,
#  -27.207046894342096,
#  6735.880829015544,
#  236.4761624917358,
#  7260.7692307692305,
#  185.79215686274512,
#  2427.083333333333,
#  -97.1393213692159,
#  -99.10811390781446,
#  924.4959987688519,
#  67741.66666666666,
#  1399.0300803281489,
#  906.9376227897841,
#  3211.8120971740204,
#  321.98710762331837,
#  7798.913043478261,
#  989.7480620155038,
#  -98.14382969120247,
#  141.63800919987614,
#  592.8908544259544,
#  2.756529635387007,
#  -94.6072319201995,
#  339.57082303073116,
#  -32.758330373871836,
#  1365.0576368876082,
#  15679.268826619964,
#  -70.04230542348067,
#  5554.349967170058,
#  4244.026548672566,
#  -1,
#  27550.0,
#  132.7737524237167]

# %%
data_05_2 = pd.DataFrame({"code": code, "mean": per_05_2})
data_05_2.plot(x = "code", y = "mean", kind = 'bar')

# %% [markdown]
# ### 6월 데이터 가공

# %%
adstrd_code_06 = card_06['adstrd_code']
mrhst_induty_cl_code_06 = card_06['mrhst_induty_cl_code']

adstrd_code_new = []
mrhst_induty_cl_code_new = []

for i in adstrd_code_06:
    adstrd_code_new.append(int(i/100000))
    
for i in mrhst_induty_cl_code_06:
    mrhst_induty_cl_code_new.append(int(i/100))

adstrd_code_new

data_card06 = {"receipt_dttm" : card_06['receipt_dttm'], "adstrd_code" : adstrd_code_new, "adstrd_nm" : card_06['adstrd_nm'],
               "mrhst_induty_cl_code": mrhst_induty_cl_code_new, "mrhst_induty_cl_nm" : card_06['mrhst_induty_cl_nm'],
               "selng_cascnt" : card_06['selng_cascnt'], "salamt" : card_06['salamt']}

df_card06 = pd.DataFrame(data_card06)
df_card06.head() # 6월은 14알 까지로, 상반기까지만 존재
# Out:
#    receipt_dttm  adstrd_code adstrd_nm  mrhst_induty_cl_code  \
# 0      20200601        11560      대림2동                    80
# 1      20200601        11200    성수2가1동                    80
# 2      20200601        11560      신길1동                    90
# 3      20200601        11680      일원본동                    40
# 4      20200601        11560      양평2동                    71
#
#   mrhst_induty_cl_nm  selng_cascnt    salamt
# 0                 주점            74   5471100
# 1               일반한식           429  11876060
# 2             기타건축자재             3     59800
# 3              슈퍼 마켓           145   2293030
# 4                사우나            12    102500

# %% [markdown]
# ### 6월 상반기 (14일까지)

# %%
seoul06 = []
seoul06_sum = []

is_code = df_card06['adstrd_code'] == 11170

for i in code:
    is_name = df_card06['mrhst_induty_cl_code'] == i
    seoul = df_card06[is_code & is_name]
    seoul06.append(seoul)
    seoul = seoul.astype({'selng_cascnt' : int})
    sum_num = sum(seoul['selng_cascnt'])
    seoul06_sum.append(sum_num)
    
print(seoul06_sum)
print(code)

mean = []

for i in seoul06_sum:
    mean.append(i/15)

Jongrogu06 = pd.DataFrame({'code' : code, 'total_sum' : seoul06_sum, 'mean' : mean})
Jongrogu06
# Out:
# [3925, 277, 4007, 14310, 20885, 386, 10194, 450, 9042, 604, 4080772, 821103, 5325, 79, 4772, 7672, 948, 7034, 456, 9812, 26608, 58635, 14800, 389497, 27, 488, 138830, 519, 2437, 925286, 3154, 990, 0, 10, 11310]
# [10, 11, 20, 21, 22, 30, 31, 32, 33, 34, 40, 41, 42, 43, 44, 50, 51, 52, 60, 61, 62, 70, 71, 80, 81, 82, 83, 84, 90, 91, 92, 93, 95, 96, 99]
#     code  total_sum           mean
# 0     10       3925     261.666667
# 1     11        277      18.466667
# 2     20       4007     267.133333
# 3     21      14310     954.000000
# 4     22      20885    1392.333333
# 5     30        386      25.733333
# 6     31      10194     679.600000
# 7     32        450      30.000000
# 8     33       9042     602.800000
# 9     34        604      40.266667
# 10    40    4080772  272051.466667
# 11    41     821103   54740.200000
# 12    42       5325     355.000000
# 13    43         79       5.266667
# 14    44       4772     318.133333
# 15    50       7672     511.466667
# 16    51        948      63.200000
# 17    52       7034     468.933333
# 18    60        456      30.400000
# 19    61       9812     654.133333
# 20    62      26608    1773.866667
# 21    70      58635    3909.000000
# 22    71      14800     986.666667
# 23    80     389497   25966.466667
# 24    81         27       1.800000
# 25    82        488      32.533333
# 26    83     138830    9255.333333
# 27    84        519      34.600000
# 28    90       2437     162.466667
# 29    91     925286   61685.733333
# 30    92       3154     210.266667
# 31    93        990      66.000000
# 32    95          0       0.000000
# 33    96         10       0.666667
# 34    99      11310     754.000000

# %% [markdown]
# ### 1월&6월(상반기) 평균 비교

# %%
per_06 = []

for i in range(0, len(Jongrogu01['mean'])) :
    a = Jongrogu01['mean'][i]
    b = Jongrogu06['mean'][i]
    if(a != 0):
        per_06.append( ( ( b - a ) / a ) * 100 )
    else:
        per_06.append(-1)
per_06
# Out:
# [5.586780035547871,
#  64.14814814814814,
#  37.64691448901974,
#  12.904180227397614,
#  -64.51491541056822,
#  273.3333333333333,
#  39.78402997135092,
#  330.7692307692308,
#  164.7592156862745,
#  91.74603174603175,
#  4.428288113626907,
#  149.1714095742519,
#  52.97014465989535,
#  514.4444444444445,
#  52.24292143793083,
#  75.84806810740014,
#  -12.265741199801688,
#  5.142002989536622,
#  428.695652173913,
#  136.6373815676141,
#  86.81410714509596,
#  21.02702463620683,
#  -3.4167715471029716,
#  -20.06997778564429,
#  -99.10224438902743,
#  -67.8229129871659,
#  -20.6611232891251,
#  39.59654178674353,
#  298.34208990075894,
#  513.7753044829653,
#  93.28518275333771,
#  172.56637168141592,
#  -1,
#  1766.6666666666667,
#  115.45055617920195]

# %%
data_06 = pd.DataFrame({"code": code, "mean": per_06})
data_06.plot(x = "code", y = "mean", kind = 'bar')

# '종로구' 의 1월 평균과 2월 평균(상반기)을 각 항목별로 비교한 그래프
